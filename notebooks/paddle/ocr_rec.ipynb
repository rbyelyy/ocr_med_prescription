# %% [markdown]
# # Cyrillic OCR with PaddleOCR
#
# This project implements Optical Character Recognition (OCR) for Cyrillic text using PaddleOCR. The system supports training, inference, and evaluation of text recognition models for Russian and other Cyrillic-based languages.
#
# ## Project Structure
#
# ```
# OCR/
# ├── PaddleOCR/                # PaddleOCR framework
# ├── model/                    # Pre-trained models
# │   ├── cyrillic_PP-OCRv3_rec_infer/
# │   └── cyrillic_PP-OCRv3_rec_train/
# ├── inference/                # Exported inference models
# │   └── cyrillic_PP-OCRv3_rec/
# ├── data/                     # Dataset
# │   ├── rec/
# │   │   ├── train/           # Training images
# │   │   ├── test/            # Test images
# │   │   ├── rec_gt_train.txt # Training ground truth
# │   │   └── rec_gt_test.txt  # Test ground truth
# │   └── det/                  # Detection dataset
# └── scripts/                  # Inference and utility scripts
# ```
#
# ## Features
#
# - **Cyrillic Text Recognition**: Specialized OCR for Russian and other Cyrillic scripts
# - **Model Training**: Scripts for training custom OCR models
# - **Model Export**: Tools to export trained models for inference
# - **Batch Inference**: Process multiple images and evaluate accuracy
# - **GPU Support**: Accelerated training and inference
#
# ## Setup & Installation
#
# 1. **Install Dependencies**:
#    ```bash
#    pip install paddlepaddle-gpu paddleocr opencv-python matplotlib numpy
#    ```
#
# 2. **Download Pre-trained Models**:
#    - Cyrillic recognition model: [cyrillic_ppocr_mobile_v2.0_rec_infer](https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/cyrillic_ppocr_mobile_v2.0_rec_infer.tar)
#    - Training model: [cyrillic_ppocr_mobile_v2.0_rec_train](https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/cyrillic_ppocr_mobile_v2.0_rec_train.tar)
#
# 3. **Clone PaddleOCR Repository**:
#    ```bash
#    git clone https://github.com/PaddlePaddle/PaddleOCR.git
#    ```
#
# ## Usage
#
# ### 1. Check Environment Setup
#
# Run the first notebook cell to verify GPU and system configurations:
# ```python
# import torch
# gpu_stats = torch.cuda.get_device_properties(0)
# print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
# ```
#
# ### 2. Verify PaddlePaddle Installation
#
# ```python
# import paddle
# print(paddle.__version__)
# print(paddle.is_compiled_with_cuda())
# paddle.utils.run_check()
# ```
#
# ### 3. Perform OCR Recognition
#
# ```python
# from paddleocr import PaddleOCR
#
# ocr = PaddleOCR(
#     use_gpu=True,
#     rec_model_dir='/path/to/model',
#     rec_char_dict_path='/path/to/dict/cyrillic_dict.txt',
#     lang='ru'
# )
#
# result = ocr.ocr('image.jpg', cls=False, det=False)
# print(result)
# ```
#
# ### 4. Train Custom Model
#
# ```bash
# cd /path/to/PaddleOCR/
# python tools/train.py \
#     -c configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
#     -o Global.pretrained_model=/path/to/pretrained/model
# ```
#
# ### 5. Export Model for Inference
#
# ```bash
# python tools/export_model.py \
#     -c configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
#     -o Global.pretrained_model=./output/v3_cyrillic_mobile/best_accuracy \
#     Global.save_inference_dir=./inference/cyrillic_PP-OCRv3_rec
# ```
#
# ### 6. Batch Inference and Evaluation
#
# Run the inference script to process test images and evaluate accuracy:
# ```bash
# python inference_script.py
# ```
#
# ## Configuration Options
#
# ### Recognition Model Parameters
#
# - `use_gpu`: Enable/disable GPU acceleration
# - `rec_model_dir`: Path to recognition model
# - `rec_char_dict_path`: Path to character dictionary
# - `lang`: Language code ('ru' for Russian)
# - `rec_image_shape`: Input image dimensions (channels, height, width)
#
# ### Training Parameters
#
# Configure training options in `cyrillic_PP-OCRv3_rec.yml`:
# - Learning rate
# - Batch size
# - Number of epochs
# - Data augmentation
# - Model architecture
#
# ## Model Details
#
# - **Architecture**: PP-OCRv3 with SVTR head
# - **Input Shape**: 3 × 48 × 320 (C×H×W)
# - **Character Set**: Cyrillic alphabet (Russian)
# - **Dictionary Path**: `ppocr/utils/dict/cyrillic_dict.txt`
#
# ## Performance
#
# - **Accuracy**: Varies by dataset and image quality
# - **Speed**: ~XX ms per image on GPU (depends on hardware)
# - **Model Size**: ~XX MB
#
# ## References
#
# - [PaddleOCR GitHub](https://github.com/PaddlePaddle/PaddleOCR)
# - [Multilingual Models Documentation](https://github.com/PaddlePaddle/PaddleOCR/blob/main/doc/doc_en/multi_languages_en.md)
# - [Cyrillic Model Configuration](https://github.com/PaddlePaddle/PaddleOCR/blob/main/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml)

# %%
# Model Path
ORIGINAL_MODEL_PATH = "/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer"
TRAINED_MODEL_PATH = "/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec"
DICT_PATH = "/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt"
# Check GPU Status and Memory
import torch

# Show current GPU memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)

print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# Verify Paddle Installation and CUDA Support
import paddle

# Check Paddle version and CUDA compatibility
print(f"Paddle version: {paddle.__version__}")
print(f"CUDA enabled: {paddle.is_compiled_with_cuda()}")
paddle.utils.run_check()

# Text Recognition using PaddleOCR with Cyrillic Model
from paddleocr import PaddleOCR

# Initialize PaddleOCR with Cyrillic recognition model
ocr = PaddleOCR(
    use_gpu=False,  # Try CPU first to eliminate CUDA issues
    rec_model_dir=ORIGINAL_MODEL_PATH,
    rec_char_dict_path=DICT_PATH,
    lang="ru",  # Russian language for Cyrillic characters
)

# Run OCR on a test image (recognition only, no detection)
result = ocr.ocr(
    "/home/ubuntu/OCR/data/rec/test/images/Клопидогрел_75_мг_calibri_normal_1_42.jpg",
    cls=False,
    det=False,
)
print(result)
# Out:
# GPU = Tesla T4. Max memory = 14.568 GB.
# 0.0 GB of memory reserved.
# Paddle version: 3.0.0-rc1
# CUDA enabled: True
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# [2025/04/29 12:09:12] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ubuntu/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ubuntu/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ru', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gcu=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [[('клопидогрелт5мг', 0.9428205490112305)]]

# %%
# Train Cyrillic Recognition Model
# Change to PaddleOCR directory and run training with pre-trained model
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/train.py \
    -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
    -o Global.pretrained_model=/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/29 12:09:24] ppocr WARNING: Skipping import of the encryption module.
# [2025/04/29 12:09:24] ppocr WARNING: You are using VisualDL, the VisualDL is deprecated and removed in ppocr!
# [2025/04/29 12:09:24] ppocr INFO: Architecture :
# [2025/04/29 12:09:24] ppocr INFO:     Backbone :
# [2025/04/29 12:09:24] ppocr INFO:         last_conv_stride : [1, 2]
# [2025/04/29 12:09:24] ppocr INFO:         last_pool_type : avg
# [2025/04/29 12:09:24] ppocr INFO:         name : MobileNetV1Enhance
# [2025/04/29 12:09:24] ppocr INFO:         scale : 0.5
# [2025/04/29 12:09:24] ppocr INFO:     Head :
# [2025/04/29 12:09:24] ppocr INFO:         head_list :
# [2025/04/29 12:09:24] ppocr INFO:             CTCHead :
# [2025/04/29 12:09:24] ppocr INFO:                 Head :
# [2025/04/29 12:09:24] ppocr INFO:                     fc_decay : 1e-05
# [2025/04/29 12:09:24] ppocr INFO:                 Neck :
# [2025/04/29 12:09:24] ppocr INFO:                     depth : 2
# [2025/04/29 12:09:24] ppocr INFO:                     dims : 64
# [2025/04/29 12:09:24] ppocr INFO:                     hidden_dims : 120
# [2025/04/29 12:09:24] ppocr INFO:                     name : svtr
# [2025/04/29 12:09:24] ppocr INFO:                     use_guide : True
# [2025/04/29 12:09:24] ppocr INFO:             SARHead :
# [2025/04/29 12:09:24] ppocr INFO:                 enc_dim : 512
# [2025/04/29 12:09:24] ppocr INFO:                 max_text_length : 25
# [2025/04/29 12:09:24] ppocr INFO:         name : MultiHead
# [2025/04/29 12:09:24] ppocr INFO:     Transform : None
# [2025/04/29 12:09:24] ppocr INFO:     algorithm : SVTR_LCNet
# [2025/04/29 12:09:24] ppocr INFO:     model_type : rec
# [2025/04/29 12:09:24] ppocr INFO: Eval :
# [2025/04/29 12:09:24] ppocr INFO:     dataset :
# [2025/04/29 12:09:24] ppocr INFO:         data_dir : /home/ubuntu/OCR/data/rec/test/images
# [2025/04/29 12:09:24] ppocr INFO:         label_file_list : ['/home/ubuntu/OCR/data/rec/rec_gt_test.txt']
# [2025/04/29 12:09:24] ppocr INFO:         name : SimpleDataSet
# [2025/04/29 12:09:24] ppocr INFO:         transforms :
# [2025/04/29 12:09:24] ppocr INFO:             DecodeImage :
# [2025/04/29 12:09:24] ppocr INFO:                 channel_first : False
# [2025/04/29 12:09:24] ppocr INFO:                 img_mode : BGR
# [2025/04/29 12:09:24] ppocr INFO:             MultiLabelEncode : None
# [2025/04/29 12:09:24] ppocr INFO:             RecResizeImg :
# [2025/04/29 12:09:24] ppocr INFO:                 image_shape : [3, 48, 320]
# [2025/04/29 12:09:24] ppocr INFO:             KeepKeys :
# [2025/04/29 12:09:24] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_sar', 'length', 'valid_ratio']
# [2025/04/29 12:09:24] ppocr INFO:     loader :
# [2025/04/29 12:09:24] ppocr INFO:         batch_size_per_card : 1
# [2025/04/29 12:09:24] ppocr INFO:         drop_last : False
# [2025/04/29 12:09:24] ppocr INFO:         num_workers : 4
# [2025/04/29 12:09:24] ppocr INFO:         shuffle : False
# [2025/04/29 12:09:24] ppocr INFO: Global :
# [2025/04/29 12:09:24] ppocr INFO:     cal_metric_during_train : True
# [2025/04/29 12:09:24] ppocr INFO:     character_dict_path : /home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt
# [2025/04/29 12:09:24] ppocr INFO:     checkpoints : None
# [2025/04/29 12:09:24] ppocr INFO:     debug : False
# [2025/04/29 12:09:24] ppocr INFO:     distributed : False
# [2025/04/29 12:09:24] ppocr INFO:     epoch_num : 2
# [2025/04/29 12:09:24] ppocr INFO:     eval_batch_step : [0, 1]
# [2025/04/29 12:09:24] ppocr INFO:     infer_img : /home/ubuntu/OCR/data/rec/test/images/Клопидогрел_75_мг_calibri_blur_medium_1_42.jpg
# [2025/04/29 12:09:24] ppocr INFO:     infer_mode : False
# [2025/04/29 12:09:24] ppocr INFO:     log_smooth_window : 1
# [2025/04/29 12:09:24] ppocr INFO:     max_text_length : 25
# [2025/04/29 12:09:24] ppocr INFO:     pretrained_model : /home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# [2025/04/29 12:09:24] ppocr INFO:     print_batch_step : 1
# [2025/04/29 12:09:24] ppocr INFO:     save_epoch_step : 5
# [2025/04/29 12:09:24] ppocr INFO:     save_inference_dir : None
# [2025/04/29 12:09:24] ppocr INFO:     save_model_dir : ./output/v3_cyrillic_mobile
# [2025/04/29 12:09:24] ppocr INFO:     save_res_path : ./output/rec/predicts_ppocrv3_cyrillic.txt
# [2025/04/29 12:09:24] ppocr INFO:     tensorboard_log_dir : ./output/tensorboard_logs
# [2025/04/29 12:09:24] ppocr INFO:     use_gpu : True
# [2025/04/29 12:09:24] ppocr INFO:     use_space_char : True
# [2025/04/29 12:09:24] ppocr INFO:     use_tensorboard : True
# [2025/04/29 12:09:24] ppocr INFO:     use_visualdl : True
# [2025/04/29 12:09:24] ppocr INFO: Loss :
# [2025/04/29 12:09:24] ppocr INFO:     loss_config_list :
# [2025/04/29 12:09:24] ppocr INFO:         CTCLoss : None
# [2025/04/29 12:09:24] ppocr INFO:         SARLoss : None
# [2025/04/29 12:09:24] ppocr INFO:     name : MultiLoss
# [2025/04/29 12:09:24] ppocr INFO: Metric :
# [2025/04/29 12:09:24] ppocr INFO:     ignore_space : False
# [2025/04/29 12:09:24] ppocr INFO:     main_indicator : acc
# [2025/04/29 12:09:24] ppocr INFO:     name : RecMetric
# [2025/04/29 12:09:24] ppocr INFO: Optimizer :
# [2025/04/29 12:09:24] ppocr INFO:     beta1 : 0.9
# [2025/04/29 12:09:24] ppocr INFO:     beta2 : 0.999
# [2025/04/29 12:09:24] ppocr INFO:     lr :
# [2025/04/29 12:09:24] ppocr INFO:         learning_rate : 0.01
# [2025/04/29 12:09:24] ppocr INFO:         name : Cosine
# [2025/04/29 12:09:24] ppocr INFO:         warmup_epoch : 5
# [2025/04/29 12:09:24] ppocr INFO:     name : Adam
# [2025/04/29 12:09:24] ppocr INFO:     regularizer :
# [2025/04/29 12:09:24] ppocr INFO:         factor : 5e-05
# [2025/04/29 12:09:24] ppocr INFO:         name : L2
# [2025/04/29 12:09:24] ppocr INFO: PostProcess :
# [2025/04/29 12:09:24] ppocr INFO:     name : CTCLabelDecode
# [2025/04/29 12:09:24] ppocr INFO: Train :
# [2025/04/29 12:09:24] ppocr INFO:     dataset :
# [2025/04/29 12:09:24] ppocr INFO:         data_dir : /home/ubuntu/OCR/data/rec/train/images
# [2025/04/29 12:09:24] ppocr INFO:         ext_op_transform_idx : 1
# [2025/04/29 12:09:24] ppocr INFO:         label_file_list : ['/home/ubuntu/OCR/data/rec/rec_gt_train.txt']
# [2025/04/29 12:09:24] ppocr INFO:         name : SimpleDataSet
# [2025/04/29 12:09:24] ppocr INFO:         transforms :
# [2025/04/29 12:09:24] ppocr INFO:             DecodeImage :
# [2025/04/29 12:09:24] ppocr INFO:                 channel_first : False
# [2025/04/29 12:09:24] ppocr INFO:                 img_mode : BGR
# [2025/04/29 12:09:24] ppocr INFO:             RecConAug :
# [2025/04/29 12:09:24] ppocr INFO:                 ext_data_num : 2
# [2025/04/29 12:09:24] ppocr INFO:                 image_shape : [48, 320, 3]
# [2025/04/29 12:09:24] ppocr INFO:                 prob : 0.5
# [2025/04/29 12:09:24] ppocr INFO:             RecAug : None
# [2025/04/29 12:09:24] ppocr INFO:             MultiLabelEncode : None
# [2025/04/29 12:09:24] ppocr INFO:             RecResizeImg :
# [2025/04/29 12:09:24] ppocr INFO:                 image_shape : [3, 48, 320]
# [2025/04/29 12:09:24] ppocr INFO:             KeepKeys :
# [2025/04/29 12:09:24] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_sar', 'length', 'valid_ratio']
# [2025/04/29 12:09:24] ppocr INFO:     loader :
# [2025/04/29 12:09:24] ppocr INFO:         batch_size_per_card : 1
# [2025/04/29 12:09:24] ppocr INFO:         drop_last : True
# [2025/04/29 12:09:24] ppocr INFO:         num_workers : 4
# [2025/04/29 12:09:24] ppocr INFO:         shuffle : True
# [2025/04/29 12:09:24] ppocr INFO: profiler_options : None
# [2025/04/29 12:09:24] ppocr INFO: train with paddle 3.0.0-rc1 and device Place(gpu:0)
# [2025/04/29 12:09:24] ppocr INFO: Initialize indexes of datasets:['/home/ubuntu/OCR/data/rec/rec_gt_train.txt']
# [2025/04/29 12:09:24] ppocr INFO: Initialize indexes of datasets:['/home/ubuntu/OCR/data/rec/rec_gt_test.txt']
# W0429 12:09:24.302888 167236 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0429 12:09:24.303951 167236 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/04/29 12:09:25] ppocr INFO: train dataloader has 1 iters
# [2025/04/29 12:09:25] ppocr INFO: valid dataloader has 1 iters
# [2025/04/29 12:09:25] ppocr INFO: load pretrain successful from /home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# [2025/04/29 12:09:25] ppocr INFO: During the training process, after the 0th iteration, an evaluation is run every 1 iterations
# W0429 12:09:26.971110 167236 multiply_fwd_func.cc:76] got different data type, run type promotion automatically, this may cause data type been changed.
# [2025/04/29 12:09:27] ppocr INFO: epoch: [1/2], global_step: 1, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.375006, CTCLoss: 65.785294, SARLoss: 6.262108, loss: 72.047401, avg_reader_cost: 0.14954 s, avg_batch_cost: 1.12727 s, avg_samples: 1.0, ips: 0.88710 samples/s, eta: 0:00:01, max_mem_reserved: 292 MB, max_mem_allocated: 264 MB
# eval model:: 100%|████████████████████████████████| 1/1 [00:00<00:00,  5.26it/s]
# [2025/04/29 12:09:27] ppocr INFO: cur metric, acc: 0.0, norm_edit_dis: 0.7647082352705885, fps: 64.71992223062324
# [2025/04/29 12:09:29] ppocr INFO: save best model is to ./output/v3_cyrillic_mobile/best_accuracy
# [2025/04/29 12:09:29] ppocr INFO: best metric, acc: 0.0, is_float16: False, norm_edit_dis: 0.7647082352705885, fps: 64.71992223062324, best_epoch: 1
# [2025/04/29 12:09:31] ppocr INFO: save model in ./output/v3_cyrillic_mobile/latest
# [2025/04/29 12:09:31] ppocr INFO: epoch: [2/2], global_step: 2, lr: 0.002000, acc: 0.000000, norm_edit_dis: 0.250007, CTCLoss: 81.586418, SARLoss: 8.846446, loss: 90.432861, avg_reader_cost: 1.66029 s, avg_batch_cost: 1.71200 s, avg_samples: 1.0, ips: 0.58411 samples/s, eta: 0:00:00, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# eval model:: 100%|████████████████████████████████| 1/1 [00:00<00:00,  5.05it/s]
# [2025/04/29 12:09:31] ppocr INFO: cur metric, acc: 0.0, norm_edit_dis: 0.8235311764529414, fps: 68.45943166794522
# [2025/04/29 12:09:34] ppocr INFO: save best model is to ./output/v3_cyrillic_mobile/best_accuracy
# [2025/04/29 12:09:34] ppocr INFO: best metric, acc: 0.0, is_float16: False, norm_edit_dis: 0.8235311764529414, fps: 68.45943166794522, best_epoch: 2
# [2025/04/29 12:09:35] ppocr INFO: save model in ./output/v3_cyrillic_mobile/latest
# [2025/04/29 12:09:35] ppocr INFO: best metric, acc: 0.0, is_float16: False, norm_edit_dis: 0.8235311764529414, fps: 68.45943166794522, best_epoch: 2

# %%
# Run these as separate commands in the cell
# %cd /home/ubuntu/OCR/PaddleOCR/

# !python /home/ubuntu/OCR/PaddleOCR/tools/train.py \
    -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
    -o Global.pretrained_model=/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy \
    -o Global.use_tensorboard=true \
    -o Global.save_epoch_step=1 \
    -o Global.eval_batch_step="[0,100]"
# Out:
# /home/ubuntu/OCR/PaddleOCR
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/29 12:09:43] ppocr WARNING: Skipping import of the encryption module.
# [2025/04/29 12:09:43] ppocr WARNING: You are using VisualDL, the VisualDL is deprecated and removed in ppocr!
# [2025/04/29 12:09:43] ppocr INFO: Architecture :
# [2025/04/29 12:09:43] ppocr INFO:     Backbone :
# [2025/04/29 12:09:43] ppocr INFO:         last_conv_stride : [1, 2]
# [2025/04/29 12:09:43] ppocr INFO:         last_pool_type : avg
# [2025/04/29 12:09:43] ppocr INFO:         name : MobileNetV1Enhance
# [2025/04/29 12:09:43] ppocr INFO:         scale : 0.5
# [2025/04/29 12:09:43] ppocr INFO:     Head :
# [2025/04/29 12:09:43] ppocr INFO:         head_list :
# [2025/04/29 12:09:43] ppocr INFO:             CTCHead :
# [2025/04/29 12:09:43] ppocr INFO:                 Head :
# [2025/04/29 12:09:43] ppocr INFO:                     fc_decay : 1e-05
# [2025/04/29 12:09:43] ppocr INFO:                 Neck :
# [2025/04/29 12:09:43] ppocr INFO:                     depth : 2
# [2025/04/29 12:09:43] ppocr INFO:                     dims : 64
# [2025/04/29 12:09:43] ppocr INFO:                     hidden_dims : 120
# [2025/04/29 12:09:43] ppocr INFO:                     name : svtr
# [2025/04/29 12:09:43] ppocr INFO:                     use_guide : True
# [2025/04/29 12:09:43] ppocr INFO:             SARHead :
# [2025/04/29 12:09:43] ppocr INFO:                 enc_dim : 512
# [2025/04/29 12:09:43] ppocr INFO:                 max_text_length : 25
# [2025/04/29 12:09:43] ppocr INFO:         name : MultiHead
# [2025/04/29 12:09:43] ppocr INFO:     Transform : None
# [2025/04/29 12:09:43] ppocr INFO:     algorithm : SVTR_LCNet
# [2025/04/29 12:09:43] ppocr INFO:     model_type : rec
# [2025/04/29 12:09:43] ppocr INFO: Eval :
# [2025/04/29 12:09:43] ppocr INFO:     dataset :
# [2025/04/29 12:09:43] ppocr INFO:         data_dir : /home/ubuntu/OCR/data/rec/test/images
# [2025/04/29 12:09:43] ppocr INFO:         label_file_list : ['/home/ubuntu/OCR/data/rec/rec_gt_test.txt']
# [2025/04/29 12:09:43] ppocr INFO:         name : SimpleDataSet
# [2025/04/29 12:09:43] ppocr INFO:         transforms :
# [2025/04/29 12:09:43] ppocr INFO:             DecodeImage :
# [2025/04/29 12:09:43] ppocr INFO:                 channel_first : False
# [2025/04/29 12:09:43] ppocr INFO:                 img_mode : BGR
# [2025/04/29 12:09:43] ppocr INFO:             MultiLabelEncode : None
# [2025/04/29 12:09:43] ppocr INFO:             RecResizeImg :
# [2025/04/29 12:09:43] ppocr INFO:                 image_shape : [3, 48, 320]
# [2025/04/29 12:09:43] ppocr INFO:             KeepKeys :
# [2025/04/29 12:09:43] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_sar', 'length', 'valid_ratio']
# [2025/04/29 12:09:43] ppocr INFO:     loader :
# [2025/04/29 12:09:43] ppocr INFO:         batch_size_per_card : 1
# [2025/04/29 12:09:43] ppocr INFO:         drop_last : False
# [2025/04/29 12:09:43] ppocr INFO:         num_workers : 4
# [2025/04/29 12:09:43] ppocr INFO:         shuffle : False
# [2025/04/29 12:09:43] ppocr INFO: Global :
# [2025/04/29 12:09:43] ppocr INFO:     cal_metric_during_train : True
# [2025/04/29 12:09:43] ppocr INFO:     character_dict_path : /home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt
# [2025/04/29 12:09:43] ppocr INFO:     checkpoints : None
# [2025/04/29 12:09:43] ppocr INFO:     debug : False
# [2025/04/29 12:09:43] ppocr INFO:     distributed : False
# [2025/04/29 12:09:43] ppocr INFO:     epoch_num : 2
# [2025/04/29 12:09:43] ppocr INFO:     eval_batch_step : [0, 100]
# [2025/04/29 12:09:43] ppocr INFO:     infer_img : /home/ubuntu/OCR/data/rec/test/images/Клопидогрел_75_мг_calibri_blur_medium_1_42.jpg
# [2025/04/29 12:09:43] ppocr INFO:     infer_mode : False
# [2025/04/29 12:09:43] ppocr INFO:     log_smooth_window : 1
# [2025/04/29 12:09:43] ppocr INFO:     max_text_length : 25
# [2025/04/29 12:09:43] ppocr INFO:     pretrained_model : /home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# [2025/04/29 12:09:43] ppocr INFO:     print_batch_step : 1
# [2025/04/29 12:09:43] ppocr INFO:     save_epoch_step : 5
# [2025/04/29 12:09:43] ppocr INFO:     save_inference_dir : None
# [2025/04/29 12:09:43] ppocr INFO:     save_model_dir : ./output/v3_cyrillic_mobile
# [2025/04/29 12:09:43] ppocr INFO:     save_res_path : ./output/rec/predicts_ppocrv3_cyrillic.txt
# [2025/04/29 12:09:43] ppocr INFO:     tensorboard_log_dir : ./output/tensorboard_logs
# [2025/04/29 12:09:43] ppocr INFO:     use_gpu : True
# [2025/04/29 12:09:43] ppocr INFO:     use_space_char : True
# [2025/04/29 12:09:43] ppocr INFO:     use_tensorboard : True
# [2025/04/29 12:09:43] ppocr INFO:     use_visualdl : True
# [2025/04/29 12:09:43] ppocr INFO: Loss :
# [2025/04/29 12:09:43] ppocr INFO:     loss_config_list :
# [2025/04/29 12:09:43] ppocr INFO:         CTCLoss : None
# [2025/04/29 12:09:43] ppocr INFO:         SARLoss : None
# [2025/04/29 12:09:43] ppocr INFO:     name : MultiLoss
# [2025/04/29 12:09:43] ppocr INFO: Metric :
# [2025/04/29 12:09:43] ppocr INFO:     ignore_space : False
# [2025/04/29 12:09:43] ppocr INFO:     main_indicator : acc
# [2025/04/29 12:09:43] ppocr INFO:     name : RecMetric
# [2025/04/29 12:09:43] ppocr INFO: Optimizer :
# [2025/04/29 12:09:43] ppocr INFO:     beta1 : 0.9
# [2025/04/29 12:09:43] ppocr INFO:     beta2 : 0.999
# [2025/04/29 12:09:43] ppocr INFO:     lr :
# [2025/04/29 12:09:43] ppocr INFO:         learning_rate : 0.01
# [2025/04/29 12:09:43] ppocr INFO:         name : Cosine
# [2025/04/29 12:09:43] ppocr INFO:         warmup_epoch : 5
# [2025/04/29 12:09:43] ppocr INFO:     name : Adam
# [2025/04/29 12:09:43] ppocr INFO:     regularizer :
# [2025/04/29 12:09:43] ppocr INFO:         factor : 5e-05
# [2025/04/29 12:09:43] ppocr INFO:         name : L2
# [2025/04/29 12:09:43] ppocr INFO: PostProcess :
# [2025/04/29 12:09:43] ppocr INFO:     name : CTCLabelDecode
# [2025/04/29 12:09:43] ppocr INFO: Train :
# [2025/04/29 12:09:43] ppocr INFO:     dataset :
# [2025/04/29 12:09:43] ppocr INFO:         data_dir : /home/ubuntu/OCR/data/rec/train/images
# [2025/04/29 12:09:43] ppocr INFO:         ext_op_transform_idx : 1
# [2025/04/29 12:09:43] ppocr INFO:         label_file_list : ['/home/ubuntu/OCR/data/rec/rec_gt_train.txt']
# [2025/04/29 12:09:43] ppocr INFO:         name : SimpleDataSet
# [2025/04/29 12:09:43] ppocr INFO:         transforms :
# [2025/04/29 12:09:43] ppocr INFO:             DecodeImage :
# [2025/04/29 12:09:43] ppocr INFO:                 channel_first : False
# [2025/04/29 12:09:43] ppocr INFO:                 img_mode : BGR
# [2025/04/29 12:09:43] ppocr INFO:             RecConAug :
# [2025/04/29 12:09:43] ppocr INFO:                 ext_data_num : 2
# [2025/04/29 12:09:43] ppocr INFO:                 image_shape : [48, 320, 3]
# [2025/04/29 12:09:43] ppocr INFO:                 prob : 0.5
# [2025/04/29 12:09:43] ppocr INFO:             RecAug : None
# [2025/04/29 12:09:43] ppocr INFO:             MultiLabelEncode : None
# [2025/04/29 12:09:43] ppocr INFO:             RecResizeImg :
# [2025/04/29 12:09:43] ppocr INFO:                 image_shape : [3, 48, 320]
# [2025/04/29 12:09:43] ppocr INFO:             KeepKeys :
# [2025/04/29 12:09:43] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_sar', 'length', 'valid_ratio']
# [2025/04/29 12:09:43] ppocr INFO:     loader :
# [2025/04/29 12:09:43] ppocr INFO:         batch_size_per_card : 1
# [2025/04/29 12:09:43] ppocr INFO:         drop_last : True
# [2025/04/29 12:09:43] ppocr INFO:         num_workers : 4
# [2025/04/29 12:09:43] ppocr INFO:         shuffle : True
# [2025/04/29 12:09:43] ppocr INFO: profiler_options : None
# [2025/04/29 12:09:43] ppocr INFO: train with paddle 3.0.0-rc1 and device Place(gpu:0)
# [2025/04/29 12:09:43] ppocr INFO: Initialize indexes of datasets:['/home/ubuntu/OCR/data/rec/rec_gt_train.txt']
# [2025/04/29 12:09:43] ppocr INFO: Initialize indexes of datasets:['/home/ubuntu/OCR/data/rec/rec_gt_test.txt']
# W0429 12:09:43.637807 167331 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0429 12:09:43.638840 167331 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/04/29 12:09:45] ppocr INFO: train dataloader has 1 iters
# [2025/04/29 12:09:45] ppocr INFO: valid dataloader has 1 iters
# [2025/04/29 12:09:45] ppocr INFO: load pretrain successful from /home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# [2025/04/29 12:09:45] ppocr INFO: During the training process, after the 0th iteration, an evaluation is run every 100 iterations
# W0429 12:09:46.315397 167331 multiply_fwd_func.cc:76] got different data type, run type promotion automatically, this may cause data type been changed.
# [2025/04/29 12:09:46] ppocr INFO: epoch: [1/2], global_step: 1, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.375006, CTCLoss: 65.785294, SARLoss: 6.262108, loss: 72.047401, avg_reader_cost: 0.15062 s, avg_batch_cost: 1.13050 s, avg_samples: 1.0, ips: 0.88457 samples/s, eta: 0:00:01, max_mem_reserved: 292 MB, max_mem_allocated: 264 MB
# [2025/04/29 12:09:47] ppocr INFO: save model in ./output/v3_cyrillic_mobile/latest
# [2025/04/29 12:09:47] ppocr INFO: epoch: [2/2], global_step: 2, lr: 0.002000, acc: 0.000000, norm_edit_dis: 0.187508, CTCLoss: 102.842018, SARLoss: 7.117638, loss: 109.959656, avg_reader_cost: 1.00434 s, avg_batch_cost: 1.05646 s, avg_samples: 1.0, ips: 0.94656 samples/s, eta: 0:00:00, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/29 12:09:48] ppocr INFO: save model in ./output/v3_cyrillic_mobile/latest
# [2025/04/29 12:09:48] ppocr INFO: best metric, acc: 0, is_float16: False

# %%
# Export Trained Model for Inference
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/export_model.py \
    -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
    -o Global.pretrained_model=./output/v3_cyrillic_mobile/best_accuracy \
    Global.save_inference_dir=./inference/cyrillic_PP-OCRv3_rec

# Run Inference with Exported Model
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/infer/predict_rec.py \
    --image_dir=/home/ubuntu/OCR/data/rec/test/images/Клопидогрел_75_мг_calibri_normal_1_42.jpg \
    --rec_model_dir=/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec \
    --rec_char_dict_path=/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt \
    --rec_image_shape="3, 48, 320"
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/29 12:10:35] ppocr WARNING: Skipping import of the encryption module.
# W0429 12:10:36.727725 167456 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0429 12:10:36.728470 167456 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/04/29 12:10:38] ppocr INFO: load pretrain successful from ./output/v3_cyrillic_mobile/best_accuracy
# [2025/04/29 12:10:38] ppocr INFO: Export inference config file to ./inference/cyrillic_PP-OCRv3_rec/inference.yml
# Skipping import of the encryption module
# I0429 12:10:39.745288 167456 program_interpreter.cc:243] New Executor is Running.
# [2025/04/29 12:10:39] ppocr INFO: inference model is saved to ./inference/cyrillic_PP-OCRv3_rec/inference
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/29 12:10:43] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/04/29 12:10:45] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2025/04/29 12:10:46] ppocr INFO: Predicts of /home/ubuntu/OCR/data/rec/test/images/Клопидогрел_75_мг_calibri_normal_1_42.jpg:('клопидогрелт5мг', 0.94282066822052)

# %%
# Cell 7: Test Recognition with Exported Model using PaddleOCR API
from paddleocr import PaddleOCR

# Path to the inference model
model_path = ORIGINAL_MODEL_PATH

# Initialize OCR with GPU
ocr = PaddleOCR(
    use_gpu=True,  # Using GPU for faster inference
    rec_model_dir=model_path,
    rec_char_dict_path=DICT_PATH,
    lang="ru",  # Russian language
)

import os
for i in os.listdir("/home/ubuntu/OCR/data/rec/train/images"):
    # Run recognition on test image
    result = ocr.ocr(
        "/home/ubuntu/OCR/data/rec/train/images/"+i,
        cls=False,
        det=False,
    )
    print(result)
# Out:
# [2025/04/29 12:10:54] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ubuntu/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ubuntu/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, formula=False, formula_algorithm='LaTeXOCR', formula_batch_num=1, formula_char_dict_path=None, formula_model_dir=None, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ru', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', onnx_providers=False, onnx_sess_options=False, output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer', recovery=False, recovery_to_markdown=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gcu=False, use_gpu=True, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [2025/04/29 12:10:54] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/04/29 12:10:55] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [[('ихA отрицатепыно', 0.9332669377326965)]]

# %%
import os
import numpy as np
import cv2
import paddle
from paddle import inference
from glob import glob
import matplotlib.pyplot as plt
import Levenshtein
import re

# Configuration - Edit these paths as needed
MODEL_PATH = TRAINED_MODEL_PATH
DICT_PATH = DICT_PATH
# TEST_FOLDER = "/home/ubuntu/OCR/data/rec/test"
# GROUND_TRUTH_FILE = "/home/ubuntu/OCR/data/rec/rec_gt_test.txt"
TEST_FOLDER = "/home/ubuntu/OCR/data/rec/train"
GROUND_TRUTH_FILE = "/home/ubuntu/OCR/data/rec/rec_gt_train.txt"

IMAGE_SHAPE = "3, 48, 320"  # Channels, Height, Width

# Load character dictionary
def load_character_dict(dict_path):
    with open(dict_path, "rb") as f:
        lines = f.readlines()
        character_dict = {}
        for idx, line in enumerate(lines):
            line = line.decode("utf-8").strip("\n").strip("\r\n")
            character_dict[idx] = line
    return character_dict


# Calculate Character Error Rate (CER)
def calculate_cer(reference, hypothesis):
    """
    Calculate Character Error Rate (CER).
    CER = (Substitutions + Insertions + Deletions) / Length of Reference
    """
    if len(reference) == 0:
        return 0 if len(hypothesis) == 0 else 1

    edit_distance = Levenshtein.distance(reference, hypothesis)
    return edit_distance / len(reference)


# Calculate Word Error Rate (WER)
def calculate_wer(reference, hypothesis):
    """
    Calculate Word Error Rate (WER).
    WER = (Substitutions + Insertions + Deletions) / Number of Words in Reference
    """
    # Split text into words
    reference_words = re.findall(r"\S+", reference)
    hypothesis_words = re.findall(r"\S+", hypothesis)

    if len(reference_words) == 0:
        return 0 if len(hypothesis_words) == 0 else 1

    # Calculate edit distance between word arrays
    edit_distance = Levenshtein.distance(reference_words, hypothesis_words)
    return edit_distance / len(reference_words)


# Load ground truth
character_dict = load_character_dict(DICT_PATH)
gt_dict = {}
with open(GROUND_TRUTH_FILE, "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split("\t")
        if len(parts) >= 2:
            image_path = parts[0]
            image_name = os.path.basename(image_path)
            text = parts[1]
            gt_dict[image_name] = text

print(f"Loaded {len(character_dict)} characters and {len(gt_dict)} ground truth labels")

# Setup predictor
config = inference.Config(
    os.path.join(MODEL_PATH, "inference.pdmodel"),
    os.path.join(MODEL_PATH, "inference.pdiparams"),
)
config.enable_use_gpu(500, 0)  # Using GPU with 500MB memory
predictor = inference.create_predictor(config)

# Get input and output tensors
input_names = predictor.get_input_names()
input_tensor = predictor.get_input_handle(input_names[0])
output_names = predictor.get_output_names()
output_tensor = predictor.get_output_handle(output_names[0])

# Get image files
extensions = ["jpg", "jpeg", "png", "bmp", "tiff"]
image_files = []
for ext in extensions:
    image_files.extend(glob(os.path.join(TEST_FOLDER, f"*.{ext}")))
    image_files.extend(glob(os.path.join(TEST_FOLDER, "images", f"*.{ext}")))
    image_files.extend(glob(os.path.join(TEST_FOLDER, f"*.{ext.upper()}")))
    image_files.extend(glob(os.path.join(TEST_FOLDER, "images", f"*.{ext.upper()}")))
image_files = sorted(image_files)

print(f"Found {len(image_files)} images in test folder")

# Results tracking
total = 0
correct = 0
total_cer = 0
total_wer = 0
incorrect_samples = []

# Create output directory for results
results_dir = os.path.join(os.path.dirname(TEST_FOLDER), "evaluation_results")
os.makedirs(results_dir, exist_ok=True)

# Create CSV file for detailed results
csv_path = os.path.join(results_dir, "ocr_evaluation_results.csv")
with open(csv_path, "w", encoding="utf-8") as csv_file:
    csv_file.write("Image,Ground Truth,Prediction,Confidence,CER,WER\n")

    # Process each image
    print(f"Processing images with GPU...")
    for image_file in image_files:  # Remove the slice [:20] to process all images
        # Get ground truth
        image_name = os.path.basename(image_file)
        gt_text = gt_dict.get(image_name, "")

        if not gt_text:
            print(f"Warning: No ground truth found for {image_name}")
            continue

        # Read and preprocess image
        img = cv2.imread(image_file)
        if img is None:
            print(f"Error reading image: {image_file}")
            continue

        # Preprocess image
        img_c, img_h, img_w = [int(v) for v in IMAGE_SHAPE.split(",")]
        img_display = img.copy()  # Save a copy for display
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (img_w, img_h))
        img = np.transpose(img, (2, 0, 1))  # HWC to CHW
        img = img.astype("float32")
        img = img / 255.0
        img = img - 0.5
        img = img / 0.5
        img = np.expand_dims(img, axis=0)  # Add batch dimension

        # Run inference
        input_tensor.copy_from_cpu(img)
        predictor.run()
        output = output_tensor.copy_to_cpu()

        # Process prediction (CTC decoding)
        pred_indices = np.argmax(output[0], axis=1)

        # Remove duplicate indices
        keep_indices = []
        prev_index = None
        for idx in pred_indices:
            if idx != prev_index:
                keep_indices.append(idx)
                prev_index = idx

        # Remove blank label (usually index 0)
        non_blank_indices = [idx for idx in keep_indices if idx > 0]

        # Convert indices to characters
        characters = [character_dict.get(idx, "") for idx in non_blank_indices]
        pred_text = "".join(characters)
        confidence = float(np.mean(np.max(output[0], axis=1)))

        # Calculate metrics
        cer = calculate_cer(gt_text, pred_text)
        wer = calculate_wer(gt_text, pred_text)
        total_cer += cer
        total_wer += wer

        # Update stats
        total += 1
        if pred_text == gt_text:
            correct += 1
            print(
                f"✓ {image_name}: '{pred_text}' (conf: {confidence:.2f}, CER: {cer:.4f}, WER: {wer:.4f})"
            )
        else:
            incorrect_samples.append(
                {
                    "image": image_name,
                    "predicted": pred_text,
                    "expected": gt_text,
                    "confidence": confidence,
                    "cer": cer,
                    "wer": wer,
                    "image_data": img_display,
                }
            )
            print(
                f"✗ {image_name}: Predicted '{pred_text}' but expected '{gt_text}' (conf: {confidence:.2f}, CER: {cer:.4f}, WER: {wer:.4f})"
            )

        # Write to CSV
        csv_file.write(
            f'{image_name},"{gt_text}","{pred_text}",{confidence:.4f},{cer:.4f},{wer:.4f}\n'
        )

# Calculate overall metrics
accuracy = correct / total if total > 0 else 0
avg_cer = total_cer / total if total > 0 else 0
avg_wer = total_wer / total if total > 0 else 0

# Print results
print("\n===== RESULTS =====")
print(f"Total images processed: {total}")
print(f"Correctly predicted: {correct}")
print(f"Accuracy: {accuracy:.2%}")
print(f"Average CER: {avg_cer:.4f}")
print(f"Average WER: {avg_wer:.4f}")

# Save results to summary file
summary_path = os.path.join(results_dir, "summary.txt")
with open(summary_path, "w", encoding="utf-8") as summary_file:
    summary_file.write("===== OCR EVALUATION SUMMARY =====\n")
    summary_file.write(f"Model: {MODEL_PATH}\n")
    summary_file.write(f"Test data: {TEST_FOLDER}\n\n")
    summary_file.write(f"Total images processed: {total}\n")
    summary_file.write(f"Correctly predicted: {correct}\n")
    summary_file.write(f"Accuracy: {accuracy:.2%}\n")
    summary_file.write(f"Average CER: {avg_cer:.4f}\n")
    summary_file.write(f"Average WER: {avg_wer:.4f}\n")

    # Sort incorrect samples by CER (highest error first)
    incorrect_samples.sort(key=lambda x: x["cer"], reverse=True)

    if incorrect_samples:
        summary_file.write("\n===== TOP 10 WORST PREDICTIONS (by CER) =====\n")
        for i, sample in enumerate(incorrect_samples[:10]):
            summary_file.write(f"{i+1}. {sample['image']}:\n")
            summary_file.write(f"   Expected: '{sample['expected']}'\n")
            summary_file.write(f"   Predicted: '{sample['predicted']}'\n")
            summary_file.write(
                f"   CER: {sample['cer']:.4f}, WER: {sample['wer']:.4f}\n\n"
            )

print(f"\nResults saved to {results_dir}")

# Display some incorrect predictions with images
if incorrect_samples and len(incorrect_samples) > 0:
    print("\n===== DISPLAYING SOME INCORRECT PREDICTIONS =====")
    num_to_display = min(5, len(incorrect_samples))

    plt.figure(figsize=(15, 4 * num_to_display))
    for i in range(num_to_display):
        sample = incorrect_samples[i]
        plt.subplot(num_to_display, 1, i + 1)
        plt.imshow(cv2.cvtColor(sample["image_data"], cv2.COLOR_BGR2RGB))
        plt.title(
            f"Expected: '{sample['expected']}', Predicted: '{sample['predicted']}'\nCER: {sample['cer']:.4f}, WER: {sample['wer']:.4f}, Conf: {sample['confidence']:.2f}"
        )
        plt.axis("off")

    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, "incorrect_samples.png"))
    plt.show()
# Out:
# Loaded 163 characters and 1 ground truth labels
# Found 1 images in test folder
# Processing images with GPU...
# ✗ ИХА_отрицательно_russia_normal_6_42.jpg: Predicted 'йцBпусйчбужмьоп' but expected 'ИХА отрицательно' (conf: 0.92, CER: 0.9375, WER: 1.0000)
#
# ===== RESULTS =====
# Total images processed: 1
# Correctly predicted: 0
# Accuracy: 0.00%
# Average CER: 0.9375
# Average WER: 1.0000
#
# Results saved to /home/ubuntu/OCR/data/rec/evaluation_results
#
# ===== DISPLAYING SOME INCORRECT PREDICTIONS =====
# --- Running analysis [ir_graph_build_pass]
# --- Running analysis [ir_analysis_pass]
# --- Running IR pass [map_op_to_another_pass]
# --- Running IR pass [is_test_pass]
# --- Running IR pass [simplify_with_basic_ops_pass]
# --- Running IR pass [delete_quant_dequant_linear_op_pass]
# --- Running IR pass [delete_weight_dequant_linear_op_pass]
# --- Running IR pass [sparse_conv_optim_pass]
# --- Running IR pass [constant_folding_pass]
# --- Running IR pass [silu_fuse_pass]
# --- Running IR pass [conv_bn_fuse_pass]
# --- Running IR pass [conv_eltwiseadd_bn_fuse_pass]
# --- Running IR pass [embedding_eltwise_layernorm_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v2]
# --- Running IR pass [vit_attention_fuse_pass]
# --- Running IR pass [fused_multi_transformer_encoder_pass]
# --- Running IR pass [fused_multi_transformer_decoder_pass]
# --- Running IR pass [fused_multi_transformer_encoder_fuse_qkv_pass]
# --- Running IR pass [fused_multi_transformer_decoder_fuse_qkv_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_encoder_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_encoder_fuse_qkv_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_decoder_fuse_qkv_pass]
# --- Running IR pass [fuse_multi_transformer_layer_pass]
# --- Running IR pass [gpu_cpu_squeeze2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_reshape2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_flatten2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_map_matmul_v2_to_mul_pass]
# --- Running IR pass [gpu_cpu_map_matmul_v2_to_matmul_pass]
# --- Running IR pass [matmul_scale_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v3]
# --- Running IR pass [gpu_cpu_map_matmul_to_mul_pass]
# --- Running IR pass [fc_fuse_pass]
# --- Running IR pass [fc_elementwise_layernorm_fuse_pass]
# --- Running IR pass [conv_elementwise_add_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add2_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add_fuse_pass]
# --- Running IR pass [transpose_flatten_concat_fuse_pass]
# --- Running IR pass [transfer_layout_pass]
# --- Running IR pass [transfer_layout_elim_pass]
# --- Running IR pass [auto_mixed_precision_pass]
# --- Running IR pass [identity_op_clean_pass]
# --- Running IR pass [inplace_op_var_pass]
# --- Running analysis [ir_params_sync_among_devices_pass]
# --- Running analysis [adjust_cudnn_workspace_size_pass]
# --- Running analysis [inference_op_replace_pass]
# --- Running analysis [save_optimized_model_pass]
# --- Running analysis [ir_graph_to_program_pass]
