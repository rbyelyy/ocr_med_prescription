# %% [markdown]
# https://github.com/Mushroomcat9998/PaddleOCR/blob/main/doc/doc_en/multi_languages_en.md
#
# https://github.com/Mushroomcat9998/PaddleOCR/blob/main/doc/doc_en/multi_languages_en.md#:~:text=rec_cyrillic_lite_train.yml
#
# https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/cyrillic_ppocr_mobile_v2.0_rec_infer.tar
#
# https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/cyrillic_ppocr_mobile_v2.0_rec_train.tar
#
#
#
# https://github.com/PaddlePaddle/PaddleOCR/blob/main/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml

# %% [markdown]
# ENV

# %%
import torch
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.568 GB.
# 0.0 GB of memory reserved.

# %%
import paddle
print(paddle.__version__)
print(paddle.is_compiled_with_cuda())
paddle.utils.run_check()
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# 3.0.0-rc1
# True
# Running verify PaddlePaddle program ...
# I0403 14:53:30.443197 62016 pir_interpreter.cc:1508] New Executor is Running ...
# W0403 14:53:30.445494 62016 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0403 14:53:30.452620 62016 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# I0403 14:53:32.955169 62016 pir_interpreter.cc:1531] pir interpreter is running by multi-thread mode ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(
    use_gpu=False,  # Try CPU first to eliminate CUDA issues
    rec_model_dir='/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer',
    rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt',
    lang='ru'
)

result = ocr.ocr('/home/ubuntu/OCR/data/rec/test/1.jpg', cls=False, det=False)
print(result)
# Out:
# [2025/04/03 14:53:38] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ubuntu/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ubuntu/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ru', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [[('Aнна', 0.5968184471130371)]]

# %%
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/train.py -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
  -o Global.pretrained_model=/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/03 14:54:02] ppocr WARNING: Skipping import of the encryption module.
# [2025/04/03 14:54:02] ppocr INFO: Architecture :
# [2025/04/03 14:54:02] ppocr INFO:     Backbone :
# [2025/04/03 14:54:02] ppocr INFO:         last_conv_stride : [1, 2]
# [2025/04/03 14:54:02] ppocr INFO:         last_pool_type : avg
# [2025/04/03 14:54:02] ppocr INFO:         name : MobileNetV1Enhance
# [2025/04/03 14:54:02] ppocr INFO:         scale : 0.5
# [2025/04/03 14:54:02] ppocr INFO:     Head :
# [2025/04/03 14:54:02] ppocr INFO:         head_list :
# [2025/04/03 14:54:02] ppocr INFO:             CTCHead :
# [2025/04/03 14:54:02] ppocr INFO:                 Head :
# [2025/04/03 14:54:02] ppocr INFO:                     fc_decay : 1e-05
# [2025/04/03 14:54:02] ppocr INFO:                 Neck :
# [2025/04/03 14:54:02] ppocr INFO:                     depth : 2
# [2025/04/03 14:54:02] ppocr INFO:                     dims : 64
# [2025/04/03 14:54:02] ppocr INFO:                     hidden_dims : 120
# [2025/04/03 14:54:02] ppocr INFO:                     name : svtr
# [2025/04/03 14:54:02] ppocr INFO:                     use_guide : True
# [2025/04/03 14:54:02] ppocr INFO:             SARHead :
# [2025/04/03 14:54:02] ppocr INFO:                 enc_dim : 512
# [2025/04/03 14:54:02] ppocr INFO:                 max_text_length : 25
# [2025/04/03 14:54:02] ppocr INFO:         name : MultiHead
# [2025/04/03 14:54:02] ppocr INFO:     Transform : None
# [2025/04/03 14:54:02] ppocr INFO:     algorithm : SVTR_LCNet
# [2025/04/03 14:54:02] ppocr INFO:     model_type : rec
# [2025/04/03 14:54:02] ppocr INFO: Eval :
# [2025/04/03 14:54:02] ppocr INFO:     dataset :
# [2025/04/03 14:54:02] ppocr INFO:         data_dir : /home/ubuntu/OCR/data/rec/test1
# [2025/04/03 14:54:02] ppocr INFO:         label_file_list : ['/home/ubuntu/OCR/data/rec/rec_gt_test1.txt']
# [2025/04/03 14:54:02] ppocr INFO:         name : SimpleDataSet
# [2025/04/03 14:54:02] ppocr INFO:         transforms :
# [2025/04/03 14:54:02] ppocr INFO:             DecodeImage :
# [2025/04/03 14:54:02] ppocr INFO:                 channel_first : False
# [2025/04/03 14:54:02] ppocr INFO:                 img_mode : BGR
# [2025/04/03 14:54:02] ppocr INFO:             MultiLabelEncode : None
# [2025/04/03 14:54:02] ppocr INFO:             RecResizeImg :
# [2025/04/03 14:54:02] ppocr INFO:                 image_shape : [3, 48, 320]
# [2025/04/03 14:54:02] ppocr INFO:             KeepKeys :
# [2025/04/03 14:54:02] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_sar', 'length', 'valid_ratio']
# [2025/04/03 14:54:02] ppocr INFO:     loader :
# [2025/04/03 14:54:02] ppocr INFO:         batch_size_per_card : 128
# [2025/04/03 14:54:02] ppocr INFO:         drop_last : False
# [2025/04/03 14:54:02] ppocr INFO:         num_workers : 4
# [2025/04/03 14:54:02] ppocr INFO:         shuffle : False
# [2025/04/03 14:54:02] ppocr INFO: Global :
# [2025/04/03 14:54:02] ppocr INFO:     cal_metric_during_train : True
# [2025/04/03 14:54:02] ppocr INFO:     character_dict_path : /home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt
# [2025/04/03 14:54:02] ppocr INFO:     checkpoints : None
# [2025/04/03 14:54:02] ppocr INFO:     debug : False
# [2025/04/03 14:54:02] ppocr INFO:     distributed : False
# [2025/04/03 14:54:02] ppocr INFO:     epoch_num : 20
# [2025/04/03 14:54:02] ppocr INFO:     eval_batch_step : [0, 1000]
# [2025/04/03 14:54:02] ppocr INFO:     infer_img : /home/ubuntu/OCR/data/rec/test/1.jpg
# [2025/04/03 14:54:02] ppocr INFO:     infer_mode : False
# [2025/04/03 14:54:02] ppocr INFO:     log_smooth_window : 5
# [2025/04/03 14:54:02] ppocr INFO:     max_text_length : 25
# [2025/04/03 14:54:02] ppocr INFO:     pretrained_model : /home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# [2025/04/03 14:54:02] ppocr INFO:     print_batch_step : 10
# [2025/04/03 14:54:02] ppocr INFO:     save_epoch_step : 25
# [2025/04/03 14:54:02] ppocr INFO:     save_inference_dir : None
# [2025/04/03 14:54:02] ppocr INFO:     save_model_dir : ./output/v3_cyrillic_mobile
# [2025/04/03 14:54:02] ppocr INFO:     save_res_path : ./output/rec/predicts_ppocrv3_cyrillic.txt
# [2025/04/03 14:54:02] ppocr INFO:     use_gpu : True
# [2025/04/03 14:54:02] ppocr INFO:     use_space_char : True
# [2025/04/03 14:54:02] ppocr INFO:     use_visualdl : False
# [2025/04/03 14:54:02] ppocr INFO: Loss :
# [2025/04/03 14:54:02] ppocr INFO:     loss_config_list :
# [2025/04/03 14:54:02] ppocr INFO:         CTCLoss : None
# [2025/04/03 14:54:02] ppocr INFO:         SARLoss : None
# [2025/04/03 14:54:02] ppocr INFO:     name : MultiLoss
# [2025/04/03 14:54:02] ppocr INFO: Metric :
# [2025/04/03 14:54:02] ppocr INFO:     ignore_space : False
# [2025/04/03 14:54:02] ppocr INFO:     main_indicator : acc
# [2025/04/03 14:54:02] ppocr INFO:     name : RecMetric
# [2025/04/03 14:54:02] ppocr INFO: Optimizer :
# [2025/04/03 14:54:02] ppocr INFO:     beta1 : 0.9
# [2025/04/03 14:54:02] ppocr INFO:     beta2 : 0.999
# [2025/04/03 14:54:02] ppocr INFO:     lr :
# [2025/04/03 14:54:02] ppocr INFO:         learning_rate : 0.0001
# [2025/04/03 14:54:02] ppocr INFO:         name : Cosine
# [2025/04/03 14:54:02] ppocr INFO:         warmup_epoch : 5
# [2025/04/03 14:54:02] ppocr INFO:     name : Adam
# [2025/04/03 14:54:02] ppocr INFO:     regularizer :
# [2025/04/03 14:54:02] ppocr INFO:         factor : 3e-05
# [2025/04/03 14:54:02] ppocr INFO:         name : L2
# [2025/04/03 14:54:02] ppocr INFO: PostProcess :
# [2025/04/03 14:54:02] ppocr INFO:     name : CTCLabelDecode
# [2025/04/03 14:54:02] ppocr INFO: Train :
# [2025/04/03 14:54:02] ppocr INFO:     dataset :
# [2025/04/03 14:54:02] ppocr INFO:         data_dir : /home/ubuntu/OCR/data/rec/train1
# [2025/04/03 14:54:02] ppocr INFO:         ext_op_transform_idx : 1
# [2025/04/03 14:54:02] ppocr INFO:         label_file_list : ['/home/ubuntu/OCR/data/rec/rec_gt_train1.txt']
# [2025/04/03 14:54:02] ppocr INFO:         name : SimpleDataSet
# [2025/04/03 14:54:02] ppocr INFO:         transforms :
# [2025/04/03 14:54:02] ppocr INFO:             DecodeImage :
# [2025/04/03 14:54:02] ppocr INFO:                 channel_first : False
# [2025/04/03 14:54:02] ppocr INFO:                 img_mode : BGR
# [2025/04/03 14:54:02] ppocr INFO:             RecConAug :
# [2025/04/03 14:54:02] ppocr INFO:                 ext_data_num : 2
# [2025/04/03 14:54:02] ppocr INFO:                 image_shape : [48, 320, 3]
# [2025/04/03 14:54:02] ppocr INFO:                 prob : 0.5
# [2025/04/03 14:54:02] ppocr INFO:             RecAug : None
# [2025/04/03 14:54:02] ppocr INFO:             MultiLabelEncode : None
# [2025/04/03 14:54:02] ppocr INFO:             RecResizeImg :
# [2025/04/03 14:54:02] ppocr INFO:                 image_shape : [3, 48, 320]
# [2025/04/03 14:54:02] ppocr INFO:             KeepKeys :
# [2025/04/03 14:54:02] ppocr INFO:                 keep_keys : ['image', 'label_ctc', 'label_sar', 'length', 'valid_ratio']
# [2025/04/03 14:54:02] ppocr INFO:     loader :
# [2025/04/03 14:54:02] ppocr INFO:         batch_size_per_card : 1
# [2025/04/03 14:54:02] ppocr INFO:         drop_last : True
# [2025/04/03 14:54:02] ppocr INFO:         num_workers : 4
# [2025/04/03 14:54:02] ppocr INFO:         shuffle : True
# [2025/04/03 14:54:02] ppocr INFO: profiler_options : None
# [2025/04/03 14:54:02] ppocr INFO: train with paddle 3.0.0-rc1 and device Place(gpu:0)
# [2025/04/03 14:54:02] ppocr INFO: Initialize indexes of datasets:['/home/ubuntu/OCR/data/rec/rec_gt_train1.txt']
# [2025/04/03 14:54:02] ppocr INFO: Initialize indexes of datasets:['/home/ubuntu/OCR/data/rec/rec_gt_test1.txt']
# W0403 14:54:02.697600 68758 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0403 14:54:02.698729 68758 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/04/03 14:54:04] ppocr INFO: train dataloader has 2000 iters
# [2025/04/03 14:54:04] ppocr INFO: valid dataloader has 1 iters
# [2025/04/03 14:54:04] ppocr INFO: load pretrain successful from /home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy
# [2025/04/03 14:54:04] ppocr INFO: During the training process, after the 0th iteration, an evaluation is run every 1000 iterations
# W0403 14:54:06.431766 68758 multiply_fwd_func.cc:76] got different data type, run type promotion automatically, this may cause data type been changed.
# [2025/04/03 14:54:07] ppocr INFO: epoch: [1/20], global_step: 10, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.444450, CTCLoss: 21.585482, SARLoss: 7.253784, loss: 28.376986, avg_reader_cost: 0.02545 s, avg_batch_cost: 0.25674 s, avg_samples: 1.0, ips: 3.89498 samples/s, eta: 2:51:07, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:07] ppocr INFO: epoch: [1/20], global_step: 20, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.555560, CTCLoss: 8.917095, SARLoss: 6.403304, loss: 14.986703, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04774 s, avg_samples: 1.0, ips: 20.94536 samples/s, eta: 1:41:26, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:08] ppocr INFO: epoch: [1/20], global_step: 30, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.333340, CTCLoss: 35.005543, SARLoss: 6.084283, loss: 42.533180, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04700 s, avg_samples: 1.0, ips: 21.27831 samples/s, eta: 1:18:02, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:08] ppocr INFO: epoch: [1/20], global_step: 40, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.277785, CTCLoss: 51.979004, SARLoss: 4.499279, loss: 56.161221, avg_reader_cost: 0.00116 s, avg_batch_cost: 0.04649 s, avg_samples: 1.0, ips: 21.51201 samples/s, eta: 1:06:15, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:09] ppocr INFO: epoch: [1/20], global_step: 50, lr: 0.000000, acc: 0.000000, norm_edit_dis: 0.285721, CTCLoss: 181.722672, SARLoss: 8.386858, loss: 190.109528, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04611 s, avg_samples: 1.0, ips: 21.68672 samples/s, eta: 0:59:08, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:09] ppocr INFO: epoch: [1/20], global_step: 60, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 23.687546, SARLoss: 7.013158, loss: 30.700703, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04609 s, avg_samples: 1.0, ips: 21.69706 samples/s, eta: 0:54:22, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:10] ppocr INFO: epoch: [1/20], global_step: 70, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 20.755476, SARLoss: 6.708002, loss: 28.719971, avg_reader_cost: 0.00121 s, avg_batch_cost: 0.04460 s, avg_samples: 1.0, ips: 22.42066 samples/s, eta: 0:50:50, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:10] ppocr INFO: epoch: [1/20], global_step: 80, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.636367, CTCLoss: 16.876814, SARLoss: 4.983330, loss: 24.567831, avg_reader_cost: 0.00116 s, avg_batch_cost: 0.04448 s, avg_samples: 1.0, ips: 22.47954 samples/s, eta: 0:48:10, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:11] ppocr INFO: epoch: [1/20], global_step: 90, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.600004, CTCLoss: 18.588476, SARLoss: 3.278485, loss: 21.862499, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04474 s, avg_samples: 1.0, ips: 22.35147 samples/s, eta: 0:46:07, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:11] ppocr INFO: epoch: [1/20], global_step: 100, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.333340, CTCLoss: 53.829037, SARLoss: 6.352811, loss: 62.336971, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04469 s, avg_samples: 1.0, ips: 22.37449 samples/s, eta: 0:44:28, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:11] ppocr INFO: epoch: [1/20], global_step: 110, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 32.518253, SARLoss: 6.388334, loss: 36.322033, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04466 s, avg_samples: 1.0, ips: 22.39287 samples/s, eta: 0:43:06, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:12] ppocr INFO: epoch: [1/20], global_step: 120, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.588239, CTCLoss: 46.538803, SARLoss: 3.544455, loss: 51.967373, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04675 s, avg_samples: 1.0, ips: 21.39052 samples/s, eta: 0:42:06, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:12] ppocr INFO: epoch: [1/20], global_step: 130, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.555560, CTCLoss: 22.515060, SARLoss: 4.500576, loss: 25.303614, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04479 s, avg_samples: 1.0, ips: 22.32524 samples/s, eta: 0:41:08, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:13] ppocr INFO: epoch: [1/20], global_step: 140, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 18.003174, SARLoss: 6.588568, loss: 22.408615, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04655 s, avg_samples: 1.0, ips: 21.48160 samples/s, eta: 0:40:24, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:13] ppocr INFO: epoch: [1/20], global_step: 150, lr: 0.000001, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 11.783450, SARLoss: 3.642643, loss: 13.423580, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04467 s, avg_samples: 1.0, ips: 22.38674 samples/s, eta: 0:39:40, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:14] ppocr INFO: epoch: [1/20], global_step: 160, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.285721, CTCLoss: 164.416977, SARLoss: 6.222996, loss: 170.639969, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04578 s, avg_samples: 1.0, ips: 21.84583 samples/s, eta: 0:39:05, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:14] ppocr INFO: epoch: [1/20], global_step: 170, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 20.908770, SARLoss: 3.060659, loss: 22.333380, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04600 s, avg_samples: 1.0, ips: 21.73857 samples/s, eta: 0:38:34, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:15] ppocr INFO: epoch: [1/20], global_step: 180, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.625004, CTCLoss: 18.251122, SARLoss: 5.900090, loss: 22.584959, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04625 s, avg_samples: 1.0, ips: 21.62112 samples/s, eta: 0:38:07, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:15] ppocr INFO: epoch: [1/20], global_step: 190, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.411771, CTCLoss: 35.745667, SARLoss: 3.164434, loss: 38.721397, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04542 s, avg_samples: 1.0, ips: 22.01466 samples/s, eta: 0:37:41, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:16] ppocr INFO: epoch: [1/20], global_step: 200, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.333340, CTCLoss: 34.575481, SARLoss: 6.579165, loss: 40.891109, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04580 s, avg_samples: 1.0, ips: 21.83542 samples/s, eta: 0:37:19, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:16] ppocr INFO: epoch: [1/20], global_step: 210, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.421058, CTCLoss: 29.694954, SARLoss: 5.709901, loss: 35.404854, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04668 s, avg_samples: 1.0, ips: 21.42447 samples/s, eta: 0:37:00, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:16] ppocr INFO: epoch: [1/20], global_step: 220, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.545459, CTCLoss: 11.971845, SARLoss: 3.466372, loss: 19.605810, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04530 s, avg_samples: 1.0, ips: 22.07330 samples/s, eta: 0:36:41, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:17] ppocr INFO: epoch: [1/20], global_step: 230, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.545459, CTCLoss: 18.764521, SARLoss: 4.983420, loss: 23.297197, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04513 s, avg_samples: 1.0, ips: 22.15585 samples/s, eta: 0:36:22, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:17] ppocr INFO: epoch: [1/20], global_step: 240, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.454551, CTCLoss: 25.861202, SARLoss: 3.802726, loss: 28.325233, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04544 s, avg_samples: 1.0, ips: 22.00687 samples/s, eta: 0:36:06, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:18] ppocr INFO: epoch: [1/20], global_step: 250, lr: 0.000002, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 23.291561, SARLoss: 4.469026, loss: 31.600266, avg_reader_cost: 0.00113 s, avg_batch_cost: 0.04605 s, avg_samples: 1.0, ips: 21.71645 samples/s, eta: 0:35:52, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:18] ppocr INFO: epoch: [1/20], global_step: 260, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.533338, CTCLoss: 26.635176, SARLoss: 4.531802, loss: 31.166977, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04517 s, avg_samples: 1.0, ips: 22.13990 samples/s, eta: 0:35:38, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:19] ppocr INFO: epoch: [1/20], global_step: 270, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 9.770897, SARLoss: 6.034708, loss: 16.264252, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04535 s, avg_samples: 1.0, ips: 22.04876 samples/s, eta: 0:35:25, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:19] ppocr INFO: epoch: [1/20], global_step: 280, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 13.001216, SARLoss: 5.609404, loss: 18.659214, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04442 s, avg_samples: 1.0, ips: 22.51491 samples/s, eta: 0:35:12, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:20] ppocr INFO: epoch: [1/20], global_step: 290, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 41.973709, SARLoss: 4.348592, loss: 44.587231, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04487 s, avg_samples: 1.0, ips: 22.28629 samples/s, eta: 0:35:00, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:20] ppocr INFO: epoch: [1/20], global_step: 300, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.578952, CTCLoss: 40.157513, SARLoss: 2.690643, loss: 42.848156, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04502 s, avg_samples: 1.0, ips: 22.21328 samples/s, eta: 0:34:49, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:21] ppocr INFO: epoch: [1/20], global_step: 310, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.600004, CTCLoss: 29.404213, SARLoss: 3.011878, loss: 31.736204, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04411 s, avg_samples: 1.0, ips: 22.66962 samples/s, eta: 0:34:37, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:21] ppocr INFO: epoch: [1/20], global_step: 320, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.391310, CTCLoss: 47.263390, SARLoss: 5.635366, loss: 52.898758, avg_reader_cost: 0.00103 s, avg_batch_cost: 0.04355 s, avg_samples: 1.0, ips: 22.96008 samples/s, eta: 0:34:26, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:21] ppocr INFO: epoch: [1/20], global_step: 330, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.473689, CTCLoss: 96.981560, SARLoss: 4.903008, loss: 101.884567, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04541 s, avg_samples: 1.0, ips: 22.02302 samples/s, eta: 0:34:17, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:22] ppocr INFO: epoch: [1/20], global_step: 340, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 12.172269, SARLoss: 3.263616, loss: 16.413158, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04552 s, avg_samples: 1.0, ips: 21.96859 samples/s, eta: 0:34:09, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:22] ppocr INFO: epoch: [1/20], global_step: 350, lr: 0.000003, acc: 0.000000, norm_edit_dis: 0.750002, CTCLoss: 11.368467, SARLoss: 3.221446, loss: 14.205151, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04425 s, avg_samples: 1.0, ips: 22.60050 samples/s, eta: 0:34:00, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:23] ppocr INFO: epoch: [1/20], global_step: 360, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 64.990578, SARLoss: 5.202539, loss: 68.774605, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04386 s, avg_samples: 1.0, ips: 22.79948 samples/s, eta: 0:33:52, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:23] ppocr INFO: epoch: [1/20], global_step: 370, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.444450, CTCLoss: 37.856911, SARLoss: 5.420963, loss: 43.851433, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04361 s, avg_samples: 1.0, ips: 22.93141 samples/s, eta: 0:33:43, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:24] ppocr INFO: epoch: [1/20], global_step: 380, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.545459, CTCLoss: 27.778500, SARLoss: 2.556116, loss: 29.855391, avg_reader_cost: 0.00103 s, avg_batch_cost: 0.04257 s, avg_samples: 1.0, ips: 23.49188 samples/s, eta: 0:33:34, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:24] ppocr INFO: epoch: [1/20], global_step: 390, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 17.249752, SARLoss: 5.802928, loss: 19.158754, avg_reader_cost: 0.00103 s, avg_batch_cost: 0.04557 s, avg_samples: 1.0, ips: 21.94614 samples/s, eta: 0:33:28, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:25] ppocr INFO: epoch: [1/20], global_step: 400, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.428577, CTCLoss: 61.687916, SARLoss: 4.163470, loss: 65.507248, avg_reader_cost: 0.00113 s, avg_batch_cost: 0.04545 s, avg_samples: 1.0, ips: 22.00366 samples/s, eta: 0:33:22, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:25] ppocr INFO: epoch: [1/20], global_step: 410, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 14.465946, SARLoss: 2.019263, loss: 16.080057, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04398 s, avg_samples: 1.0, ips: 22.73983 samples/s, eta: 0:33:15, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:25] ppocr INFO: epoch: [1/20], global_step: 420, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 21.981417, SARLoss: 2.756788, loss: 24.422550, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04400 s, avg_samples: 1.0, ips: 22.72832 samples/s, eta: 0:33:09, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:26] ppocr INFO: epoch: [1/20], global_step: 430, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.375006, CTCLoss: 23.541115, SARLoss: 4.682628, loss: 29.450888, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04508 s, avg_samples: 1.0, ips: 22.18325 samples/s, eta: 0:33:03, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:26] ppocr INFO: epoch: [1/20], global_step: 440, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 25.385883, SARLoss: 3.931576, loss: 31.093510, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04620 s, avg_samples: 1.0, ips: 21.64519 samples/s, eta: 0:32:59, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:27] ppocr INFO: epoch: [1/20], global_step: 450, lr: 0.000004, acc: 0.000000, norm_edit_dis: 0.437506, CTCLoss: 41.630203, SARLoss: 3.210384, loss: 46.031162, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04560 s, avg_samples: 1.0, ips: 21.92904 samples/s, eta: 0:32:55, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:27] ppocr INFO: epoch: [1/20], global_step: 460, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.391310, CTCLoss: 21.156439, SARLoss: 5.270610, loss: 26.781116, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04567 s, avg_samples: 1.0, ips: 21.89688 samples/s, eta: 0:32:51, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:28] ppocr INFO: epoch: [1/20], global_step: 470, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.375006, CTCLoss: 81.110825, SARLoss: 3.699870, loss: 84.114952, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04741 s, avg_samples: 1.0, ips: 21.09410 samples/s, eta: 0:32:48, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:28] ppocr INFO: epoch: [1/20], global_step: 480, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.375006, CTCLoss: 29.882490, SARLoss: 3.476751, loss: 33.880463, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04779 s, avg_samples: 1.0, ips: 20.92437 samples/s, eta: 0:32:46, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:29] ppocr INFO: epoch: [1/20], global_step: 490, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 50.153744, SARLoss: 3.300591, loss: 52.731274, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04615 s, avg_samples: 1.0, ips: 21.66881 samples/s, eta: 0:32:43, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:29] ppocr INFO: epoch: [1/20], global_step: 500, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 18.151312, SARLoss: 4.076252, loss: 22.842918, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04458 s, avg_samples: 1.0, ips: 22.43066 samples/s, eta: 0:32:38, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:30] ppocr INFO: epoch: [1/20], global_step: 510, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.588239, CTCLoss: 16.399017, SARLoss: 3.672866, loss: 21.232948, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04418 s, avg_samples: 1.0, ips: 22.63711 samples/s, eta: 0:32:33, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:30] ppocr INFO: epoch: [1/20], global_step: 520, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 15.201803, SARLoss: 4.024541, loss: 18.489382, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04516 s, avg_samples: 1.0, ips: 22.14301 samples/s, eta: 0:32:30, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:31] ppocr INFO: epoch: [1/20], global_step: 530, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.357149, CTCLoss: 26.748857, SARLoss: 4.067046, loss: 31.513077, avg_reader_cost: 0.00113 s, avg_batch_cost: 0.04425 s, avg_samples: 1.0, ips: 22.59888 samples/s, eta: 0:32:25, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:31] ppocr INFO: epoch: [1/20], global_step: 540, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.444450, CTCLoss: 39.553959, SARLoss: 3.941391, loss: 41.895508, avg_reader_cost: 0.00115 s, avg_batch_cost: 0.04405 s, avg_samples: 1.0, ips: 22.70130 samples/s, eta: 0:32:21, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:31] ppocr INFO: epoch: [1/20], global_step: 550, lr: 0.000005, acc: 0.000000, norm_edit_dis: 0.380959, CTCLoss: 90.317741, SARLoss: 4.494163, loss: 94.063576, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04406 s, avg_samples: 1.0, ips: 22.69870 samples/s, eta: 0:32:17, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:32] ppocr INFO: epoch: [1/20], global_step: 560, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.727275, CTCLoss: 10.161804, SARLoss: 1.642664, loss: 11.804468, avg_reader_cost: 0.00116 s, avg_batch_cost: 0.04442 s, avg_samples: 1.0, ips: 22.51088 samples/s, eta: 0:32:13, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:32] ppocr INFO: epoch: [1/20], global_step: 570, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.470594, CTCLoss: 59.706818, SARLoss: 3.666893, loss: 63.373711, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04452 s, avg_samples: 1.0, ips: 22.46366 samples/s, eta: 0:32:09, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:33] ppocr INFO: epoch: [1/20], global_step: 580, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.555560, CTCLoss: 17.032650, SARLoss: 3.812256, loss: 20.204329, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04362 s, avg_samples: 1.0, ips: 22.92685 samples/s, eta: 0:32:05, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:33] ppocr INFO: epoch: [1/20], global_step: 590, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 25.557579, SARLoss: 3.202269, loss: 27.765379, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04541 s, avg_samples: 1.0, ips: 22.02255 samples/s, eta: 0:32:02, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:34] ppocr INFO: epoch: [1/20], global_step: 600, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.600004, CTCLoss: 10.222271, SARLoss: 2.067714, loss: 14.345894, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04432 s, avg_samples: 1.0, ips: 22.56361 samples/s, eta: 0:31:59, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:34] ppocr INFO: epoch: [1/20], global_step: 610, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.428577, CTCLoss: 20.115168, SARLoss: 4.083703, loss: 23.881039, avg_reader_cost: 0.00115 s, avg_batch_cost: 0.04450 s, avg_samples: 1.0, ips: 22.46954 samples/s, eta: 0:31:56, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:35] ppocr INFO: epoch: [1/20], global_step: 620, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.700003, CTCLoss: 7.969229, SARLoss: 2.225574, loss: 12.291563, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04508 s, avg_samples: 1.0, ips: 22.18424 samples/s, eta: 0:31:53, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:35] ppocr INFO: epoch: [1/20], global_step: 630, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.454551, CTCLoss: 14.215034, SARLoss: 3.516189, loss: 17.731222, avg_reader_cost: 0.00114 s, avg_batch_cost: 0.04334 s, avg_samples: 1.0, ips: 23.07587 samples/s, eta: 0:31:49, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:35] ppocr INFO: epoch: [1/20], global_step: 640, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.636367, CTCLoss: 15.847840, SARLoss: 1.767631, loss: 17.299337, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04371 s, avg_samples: 1.0, ips: 22.88062 samples/s, eta: 0:31:46, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:36] ppocr INFO: epoch: [1/20], global_step: 650, lr: 0.000006, acc: 0.000000, norm_edit_dis: 0.444450, CTCLoss: 16.722166, SARLoss: 2.928477, loss: 20.965448, avg_reader_cost: 0.00113 s, avg_batch_cost: 0.04325 s, avg_samples: 1.0, ips: 23.12255 samples/s, eta: 0:31:42, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:36] ppocr INFO: epoch: [1/20], global_step: 660, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.583337, CTCLoss: 15.321719, SARLoss: 3.095015, loss: 17.877262, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04472 s, avg_samples: 1.0, ips: 22.36344 samples/s, eta: 0:31:40, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:37] ppocr INFO: epoch: [1/20], global_step: 670, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.714289, CTCLoss: 16.807407, SARLoss: 3.550198, loss: 20.357605, avg_reader_cost: 0.00122 s, avg_batch_cost: 0.04527 s, avg_samples: 1.0, ips: 22.09008 samples/s, eta: 0:31:37, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:37] ppocr INFO: epoch: [1/20], global_step: 680, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 25.010077, SARLoss: 2.540299, loss: 27.550375, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04461 s, avg_samples: 1.0, ips: 22.41568 samples/s, eta: 0:31:35, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:38] ppocr INFO: epoch: [1/20], global_step: 690, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 15.347670, SARLoss: 3.373113, loss: 19.025148, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04465 s, avg_samples: 1.0, ips: 22.39744 samples/s, eta: 0:31:32, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:38] ppocr INFO: epoch: [1/20], global_step: 700, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.785716, CTCLoss: 10.634955, SARLoss: 1.965764, loss: 12.540855, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04437 s, avg_samples: 1.0, ips: 22.54006 samples/s, eta: 0:31:30, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:39] ppocr INFO: epoch: [1/20], global_step: 710, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 9.100345, SARLoss: 3.268870, loss: 10.583545, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04499 s, avg_samples: 1.0, ips: 22.22894 samples/s, eta: 0:31:27, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:39] ppocr INFO: epoch: [1/20], global_step: 720, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.625004, CTCLoss: 16.225376, SARLoss: 2.217958, loss: 18.169214, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04548 s, avg_samples: 1.0, ips: 21.98573 samples/s, eta: 0:31:26, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:39] ppocr INFO: epoch: [1/20], global_step: 730, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 12.191273, SARLoss: 3.482721, loss: 13.848451, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04753 s, avg_samples: 1.0, ips: 21.03736 samples/s, eta: 0:31:25, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:40] ppocr INFO: epoch: [1/20], global_step: 740, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.636367, CTCLoss: 13.870692, SARLoss: 1.838115, loss: 15.384840, avg_reader_cost: 0.00116 s, avg_batch_cost: 0.04503 s, avg_samples: 1.0, ips: 22.20868 samples/s, eta: 0:31:23, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:40] ppocr INFO: epoch: [1/20], global_step: 750, lr: 0.000007, acc: 0.000000, norm_edit_dis: 0.700003, CTCLoss: 11.134645, SARLoss: 3.035757, loss: 12.116263, avg_reader_cost: 0.00113 s, avg_batch_cost: 0.04532 s, avg_samples: 1.0, ips: 22.06448 samples/s, eta: 0:31:21, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:41] ppocr INFO: epoch: [1/20], global_step: 760, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 14.096889, SARLoss: 1.752307, loss: 17.612761, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04514 s, avg_samples: 1.0, ips: 22.15441 samples/s, eta: 0:31:19, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:41] ppocr INFO: epoch: [1/20], global_step: 770, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.437506, CTCLoss: 46.210850, SARLoss: 3.241491, loss: 48.747532, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04455 s, avg_samples: 1.0, ips: 22.44830 samples/s, eta: 0:31:17, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:42] ppocr INFO: epoch: [1/20], global_step: 780, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.625004, CTCLoss: 6.984654, SARLoss: 1.538777, loss: 8.648043, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04448 s, avg_samples: 1.0, ips: 22.48083 samples/s, eta: 0:31:15, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:42] ppocr INFO: epoch: [1/20], global_step: 790, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 63.347088, SARLoss: 2.719943, loss: 66.055153, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04357 s, avg_samples: 1.0, ips: 22.95323 samples/s, eta: 0:31:12, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:43] ppocr INFO: epoch: [1/20], global_step: 800, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.529416, CTCLoss: 54.942749, SARLoss: 2.025822, loss: 56.682705, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04371 s, avg_samples: 1.0, ips: 22.87551 samples/s, eta: 0:31:10, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:43] ppocr INFO: epoch: [1/20], global_step: 810, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.700003, CTCLoss: 7.138572, SARLoss: 1.786596, loss: 7.987981, avg_reader_cost: 0.00103 s, avg_batch_cost: 0.04216 s, avg_samples: 1.0, ips: 23.71751 samples/s, eta: 0:31:06, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:43] ppocr INFO: epoch: [1/20], global_step: 820, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.470594, CTCLoss: 12.179444, SARLoss: 1.849160, loss: 14.028605, avg_reader_cost: 0.00097 s, avg_batch_cost: 0.04142 s, avg_samples: 1.0, ips: 24.14534 samples/s, eta: 0:31:03, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:44] ppocr INFO: epoch: [1/20], global_step: 830, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 9.417950, SARLoss: 1.993876, loss: 11.455919, avg_reader_cost: 0.00098 s, avg_batch_cost: 0.04162 s, avg_samples: 1.0, ips: 24.02424 samples/s, eta: 0:31:00, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:44] ppocr INFO: epoch: [1/20], global_step: 840, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.545459, CTCLoss: 44.118256, SARLoss: 2.630538, loss: 46.000034, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04435 s, avg_samples: 1.0, ips: 22.54899 samples/s, eta: 0:30:58, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:45] ppocr INFO: epoch: [1/20], global_step: 850, lr: 0.000008, acc: 0.000000, norm_edit_dis: 0.625004, CTCLoss: 20.558704, SARLoss: 2.204998, loss: 22.061550, avg_reader_cost: 0.00098 s, avg_batch_cost: 0.04152 s, avg_samples: 1.0, ips: 24.08294 samples/s, eta: 0:30:54, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:45] ppocr INFO: epoch: [1/20], global_step: 860, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.588239, CTCLoss: 53.799156, SARLoss: 3.294273, loss: 56.412205, avg_reader_cost: 0.00101 s, avg_batch_cost: 0.04200 s, avg_samples: 1.0, ips: 23.80776 samples/s, eta: 0:30:52, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:46] ppocr INFO: epoch: [1/20], global_step: 870, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.615388, CTCLoss: 9.590376, SARLoss: 1.474286, loss: 11.064662, avg_reader_cost: 0.00097 s, avg_batch_cost: 0.04120 s, avg_samples: 1.0, ips: 24.27265 samples/s, eta: 0:30:48, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:46] ppocr INFO: epoch: [1/20], global_step: 880, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.454551, CTCLoss: 128.243393, SARLoss: 3.567072, loss: 131.810471, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04297 s, avg_samples: 1.0, ips: 23.27265 samples/s, eta: 0:30:46, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:46] ppocr INFO: epoch: [1/20], global_step: 890, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.545459, CTCLoss: 13.544137, SARLoss: 2.116070, loss: 15.198239, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04478 s, avg_samples: 1.0, ips: 22.33204 samples/s, eta: 0:30:44, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:47] ppocr INFO: epoch: [1/20], global_step: 900, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.714289, CTCLoss: 8.237962, SARLoss: 2.406433, loss: 11.489842, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04557 s, avg_samples: 1.0, ips: 21.94292 samples/s, eta: 0:30:43, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:47] ppocr INFO: epoch: [1/20], global_step: 910, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.400006, CTCLoss: 39.371246, SARLoss: 2.561424, loss: 41.754345, avg_reader_cost: 0.00105 s, avg_batch_cost: 0.04412 s, avg_samples: 1.0, ips: 22.66333 samples/s, eta: 0:30:41, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:48] ppocr INFO: epoch: [1/20], global_step: 920, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 20.731621, SARLoss: 3.267527, loss: 24.168255, avg_reader_cost: 0.00101 s, avg_batch_cost: 0.04225 s, avg_samples: 1.0, ips: 23.67108 samples/s, eta: 0:30:39, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:48] ppocr INFO: epoch: [1/20], global_step: 930, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.428577, CTCLoss: 13.132089, SARLoss: 2.375684, loss: 15.654133, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04279 s, avg_samples: 1.0, ips: 23.37147 samples/s, eta: 0:30:37, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:49] ppocr INFO: epoch: [1/20], global_step: 940, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.700003, CTCLoss: 9.969832, SARLoss: 0.855919, loss: 10.824445, avg_reader_cost: 0.00105 s, avg_batch_cost: 0.04448 s, avg_samples: 1.0, ips: 22.47966 samples/s, eta: 0:30:35, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:49] ppocr INFO: epoch: [1/20], global_step: 950, lr: 0.000009, acc: 0.000000, norm_edit_dis: 0.687503, CTCLoss: 29.938669, SARLoss: 2.169902, loss: 32.772663, avg_reader_cost: 0.00101 s, avg_batch_cost: 0.04244 s, avg_samples: 1.0, ips: 23.56352 samples/s, eta: 0:30:33, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:50] ppocr INFO: epoch: [1/20], global_step: 960, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.625004, CTCLoss: 11.303425, SARLoss: 1.381916, loss: 12.685341, avg_reader_cost: 0.00099 s, avg_batch_cost: 0.04227 s, avg_samples: 1.0, ips: 23.65961 samples/s, eta: 0:30:30, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:50] ppocr INFO: epoch: [1/20], global_step: 970, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.733336, CTCLoss: 10.102955, SARLoss: 1.303846, loss: 11.406801, avg_reader_cost: 0.00096 s, avg_batch_cost: 0.04134 s, avg_samples: 1.0, ips: 24.18757 samples/s, eta: 0:30:28, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:50] ppocr INFO: epoch: [1/20], global_step: 980, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 24.715267, SARLoss: 2.216527, loss: 25.706341, avg_reader_cost: 0.00101 s, avg_batch_cost: 0.04274 s, avg_samples: 1.0, ips: 23.39962 samples/s, eta: 0:30:26, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:51] ppocr INFO: epoch: [1/20], global_step: 990, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 25.684135, SARLoss: 2.083089, loss: 27.978477, avg_reader_cost: 0.00097 s, avg_batch_cost: 0.04141 s, avg_samples: 1.0, ips: 24.14623 samples/s, eta: 0:30:23, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:51] ppocr INFO: epoch: [1/20], global_step: 1000, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.800002, CTCLoss: 3.723185, SARLoss: 2.050719, loss: 5.773904, avg_reader_cost: 0.00096 s, avg_batch_cost: 0.04099 s, avg_samples: 1.0, ips: 24.39738 samples/s, eta: 0:30:20, max_mem_reserved: 389 MB, max_mem_allocated: 327 MB
# eval model:: 100%|████████████████████████████████| 1/1 [00:00<00:00,  3.19it/s]
# [2025/04/03 14:54:52] ppocr INFO: cur metric, acc: 0.2999997000003, norm_edit_dis: 0.79000020999979, fps: 239.3599269531473
# [2025/04/03 14:54:54] ppocr INFO: save best model is to ./output/v3_cyrillic_mobile/best_accuracy
# [2025/04/03 14:54:54] ppocr INFO: best metric, acc: 0.2999997000003, is_float16: False, norm_edit_dis: 0.79000020999979, fps: 239.3599269531473, best_epoch: 1
# [2025/04/03 14:54:54] ppocr INFO: epoch: [1/20], global_step: 1010, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.750002, CTCLoss: 17.472597, SARLoss: 1.353538, loss: 18.826134, avg_reader_cost: 0.00114 s, avg_batch_cost: 0.04646 s, avg_samples: 1.0, ips: 21.52183 samples/s, eta: 0:30:20, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:55] ppocr INFO: epoch: [1/20], global_step: 1020, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.705885, CTCLoss: 14.826812, SARLoss: 2.031772, loss: 16.858583, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04467 s, avg_samples: 1.0, ips: 22.38825 samples/s, eta: 0:30:19, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:55] ppocr INFO: epoch: [1/20], global_step: 1030, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 12.164795, SARLoss: 0.727760, loss: 12.892555, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04517 s, avg_samples: 1.0, ips: 22.13866 samples/s, eta: 0:30:18, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:56] ppocr INFO: epoch: [1/20], global_step: 1040, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.434788, CTCLoss: 43.920650, SARLoss: 3.013136, loss: 46.933784, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04401 s, avg_samples: 1.0, ips: 22.72146 samples/s, eta: 0:30:16, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:56] ppocr INFO: epoch: [1/20], global_step: 1050, lr: 0.000010, acc: 0.000000, norm_edit_dis: 0.571433, CTCLoss: 12.895090, SARLoss: 1.406758, loss: 14.301847, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04433 s, avg_samples: 1.0, ips: 22.55849 samples/s, eta: 0:30:15, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:57] ppocr INFO: epoch: [1/20], global_step: 1060, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.500005, CTCLoss: 25.042948, SARLoss: 2.816397, loss: 27.859344, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04453 s, avg_samples: 1.0, ips: 22.45850 samples/s, eta: 0:30:14, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:57] ppocr INFO: epoch: [1/20], global_step: 1070, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.444450, CTCLoss: 14.581203, SARLoss: 2.601894, loss: 17.183098, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04357 s, avg_samples: 1.0, ips: 22.94908 samples/s, eta: 0:30:12, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:57] ppocr INFO: epoch: [1/20], global_step: 1080, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.529416, CTCLoss: 25.063364, SARLoss: 2.273941, loss: 27.337305, avg_reader_cost: 0.00112 s, avg_batch_cost: 0.04268 s, avg_samples: 1.0, ips: 23.42978 samples/s, eta: 0:30:10, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:58] ppocr INFO: epoch: [1/20], global_step: 1090, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.555560, CTCLoss: 14.069295, SARLoss: 1.063113, loss: 14.703067, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04195 s, avg_samples: 1.0, ips: 23.83838 samples/s, eta: 0:30:08, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:58] ppocr INFO: epoch: [1/20], global_step: 1100, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.611115, CTCLoss: 11.047713, SARLoss: 1.619759, loss: 11.570509, avg_reader_cost: 0.00102 s, avg_batch_cost: 0.04220 s, avg_samples: 1.0, ips: 23.69509 samples/s, eta: 0:30:06, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:59] ppocr INFO: epoch: [1/20], global_step: 1110, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.777780, CTCLoss: 9.680695, SARLoss: 1.363355, loss: 10.997294, avg_reader_cost: 0.00101 s, avg_batch_cost: 0.04235 s, avg_samples: 1.0, ips: 23.61206 samples/s, eta: 0:30:04, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:54:59] ppocr INFO: epoch: [1/20], global_step: 1120, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.700003, CTCLoss: 13.659663, SARLoss: 1.041268, loss: 14.700932, avg_reader_cost: 0.00100 s, avg_batch_cost: 0.04162 s, avg_samples: 1.0, ips: 24.02731 samples/s, eta: 0:30:02, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:55:00] ppocr INFO: epoch: [1/20], global_step: 1130, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.666670, CTCLoss: 13.869297, SARLoss: 1.621721, loss: 14.693509, avg_reader_cost: 0.00100 s, avg_batch_cost: 0.04343 s, avg_samples: 1.0, ips: 23.02684 samples/s, eta: 0:30:01, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 14:55:00] ppocr INFO: epoch: [1/20], global_step: 1140, lr: 0.000011, acc: 0.000000, norm_edit_dis: 0.375006, CTCLoss: 30.011662, SARLoss: 3.120076, loss: 32.526909, avg_reader_cost: 0.00092 s, avg_batch_cost: 0.04054 s, avg_samples: 1.0, ips: 24.66888 samples/s, eta: 0:29:58, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# ...
# [2025/04/03 15:02:01] ppocr INFO: epoch: [6/20], global_step: 10140, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.461991, SARLoss: 0.342691, loss: 0.889166, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04623 s, avg_samples: 1.0, ips: 21.63047 samples/s, eta: 0:22:15, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:01] ppocr INFO: epoch: [6/20], global_step: 10150, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.412319, SARLoss: 0.347998, loss: 0.760317, avg_reader_cost: 0.00112 s, avg_batch_cost: 0.04721 s, avg_samples: 1.0, ips: 21.18376 samples/s, eta: 0:22:15, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:02] ppocr INFO: epoch: [6/20], global_step: 10160, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.439145, SARLoss: 0.284386, loss: 1.146176, avg_reader_cost: 0.00114 s, avg_batch_cost: 0.04625 s, avg_samples: 1.0, ips: 21.62102 samples/s, eta: 0:22:15, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:02] ppocr INFO: epoch: [6/20], global_step: 10170, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.162953, SARLoss: 0.414051, loss: 0.799154, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04667 s, avg_samples: 1.0, ips: 21.42788 samples/s, eta: 0:22:14, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:03] ppocr INFO: epoch: [6/20], global_step: 10180, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.115681, SARLoss: 0.339719, loss: 0.381836, avg_reader_cost: 0.00115 s, avg_batch_cost: 0.04587 s, avg_samples: 1.0, ips: 21.80195 samples/s, eta: 0:22:14, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:03] ppocr INFO: epoch: [6/20], global_step: 10190, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.208459, SARLoss: 0.003491, loss: 0.209455, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04492 s, avg_samples: 1.0, ips: 22.26017 samples/s, eta: 0:22:13, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:04] ppocr INFO: epoch: [6/20], global_step: 10200, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.156701, SARLoss: 0.292090, loss: 0.710415, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04677 s, avg_samples: 1.0, ips: 21.37952 samples/s, eta: 0:22:13, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:04] ppocr INFO: epoch: [6/20], global_step: 10210, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.195647, SARLoss: 0.360166, loss: 0.822785, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04518 s, avg_samples: 1.0, ips: 22.13515 samples/s, eta: 0:22:13, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:05] ppocr INFO: epoch: [6/20], global_step: 10220, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.123378, SARLoss: 0.003222, loss: 0.148368, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04460 s, avg_samples: 1.0, ips: 22.42308 samples/s, eta: 0:22:12, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:05] ppocr INFO: epoch: [6/20], global_step: 10230, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.044929, SARLoss: 0.014863, loss: 0.474839, avg_reader_cost: 0.00122 s, avg_batch_cost: 0.04555 s, avg_samples: 1.0, ips: 21.95272 samples/s, eta: 0:22:12, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:05] ppocr INFO: epoch: [6/20], global_step: 10240, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.166701, SARLoss: 0.333186, loss: 0.505813, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04588 s, avg_samples: 1.0, ips: 21.79823 samples/s, eta: 0:22:11, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:06] ppocr INFO: epoch: [6/20], global_step: 10250, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.536386, SARLoss: 0.282466, loss: 0.932012, avg_reader_cost: 0.00116 s, avg_batch_cost: 0.04601 s, avg_samples: 1.0, ips: 21.73213 samples/s, eta: 0:22:11, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:06] ppocr INFO: epoch: [6/20], global_step: 10260, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.553510, SARLoss: 0.010881, loss: 0.564391, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04744 s, avg_samples: 1.0, ips: 21.07962 samples/s, eta: 0:22:10, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:07] ppocr INFO: epoch: [6/20], global_step: 10270, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.365780, SARLoss: 0.235637, loss: 0.366826, avg_reader_cost: 0.00119 s, avg_batch_cost: 0.04885 s, avg_samples: 1.0, ips: 20.46899 samples/s, eta: 0:22:10, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:07] ppocr INFO: epoch: [6/20], global_step: 10280, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.144903, SARLoss: 0.190013, loss: 0.407077, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04849 s, avg_samples: 1.0, ips: 20.62295 samples/s, eta: 0:22:10, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:08] ppocr INFO: epoch: [6/20], global_step: 10290, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.337768, SARLoss: 0.005734, loss: 0.343501, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04651 s, avg_samples: 1.0, ips: 21.49871 samples/s, eta: 0:22:09, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:08] ppocr INFO: epoch: [6/20], global_step: 10300, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.111595, SARLoss: 0.321350, loss: 0.391261, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04437 s, avg_samples: 1.0, ips: 22.54012 samples/s, eta: 0:22:09, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:09] ppocr INFO: epoch: [6/20], global_step: 10310, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.362585, SARLoss: 0.520659, loss: 1.201582, avg_reader_cost: 0.00119 s, avg_batch_cost: 0.04914 s, avg_samples: 1.0, ips: 20.35137 samples/s, eta: 0:22:09, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:09] ppocr INFO: epoch: [6/20], global_step: 10320, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.737802, SARLoss: 0.379066, loss: 0.751285, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04417 s, avg_samples: 1.0, ips: 22.64082 samples/s, eta: 0:22:08, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:10] ppocr INFO: epoch: [6/20], global_step: 10330, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.161747, SARLoss: 0.343935, loss: 0.804845, avg_reader_cost: 0.00106 s, avg_batch_cost: 0.04356 s, avg_samples: 1.0, ips: 22.95625 samples/s, eta: 0:22:08, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:10] ppocr INFO: epoch: [6/20], global_step: 10340, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.109971, SARLoss: 0.131587, loss: 0.858205, avg_reader_cost: 0.00112 s, avg_batch_cost: 0.04348 s, avg_samples: 1.0, ips: 22.99863 samples/s, eta: 0:22:07, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:11] ppocr INFO: epoch: [6/20], global_step: 10350, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.241061, SARLoss: 0.394027, loss: 0.569479, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04442 s, avg_samples: 1.0, ips: 22.51239 samples/s, eta: 0:22:07, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:11] ppocr INFO: epoch: [6/20], global_step: 10360, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.093535, SARLoss: 0.417814, loss: 0.748111, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04527 s, avg_samples: 1.0, ips: 22.08740 samples/s, eta: 0:22:06, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:11] ppocr INFO: epoch: [6/20], global_step: 10370, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.060476, SARLoss: 0.547366, loss: 0.763267, avg_reader_cost: 0.00117 s, avg_batch_cost: 0.04477 s, avg_samples: 1.0, ips: 22.33542 samples/s, eta: 0:22:06, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:12] ppocr INFO: epoch: [6/20], global_step: 10380, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 1.056611, SARLoss: 0.282905, loss: 1.418005, avg_reader_cost: 0.00112 s, avg_batch_cost: 0.04579 s, avg_samples: 1.0, ips: 21.84060 samples/s, eta: 0:22:05, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:12] ppocr INFO: epoch: [6/20], global_step: 10390, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.211506, SARLoss: 0.010743, loss: 0.644013, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04456 s, avg_samples: 1.0, ips: 22.44260 samples/s, eta: 0:22:05, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:13] ppocr INFO: epoch: [6/20], global_step: 10400, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.087469, SARLoss: 0.013298, loss: 0.440208, avg_reader_cost: 0.00108 s, avg_batch_cost: 0.04427 s, avg_samples: 1.0, ips: 22.58831 samples/s, eta: 0:22:05, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:13] ppocr INFO: epoch: [6/20], global_step: 10410, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.165237, SARLoss: 0.248243, loss: 0.413480, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04484 s, avg_samples: 1.0, ips: 22.30129 samples/s, eta: 0:22:04, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:14] ppocr INFO: epoch: [6/20], global_step: 10420, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.160190, SARLoss: 0.239493, loss: 0.445123, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04445 s, avg_samples: 1.0, ips: 22.49472 samples/s, eta: 0:22:04, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:14] ppocr INFO: epoch: [6/20], global_step: 10430, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.464965, SARLoss: 0.404203, loss: 1.085658, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04511 s, avg_samples: 1.0, ips: 22.16761 samples/s, eta: 0:22:03, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:15] ppocr INFO: epoch: [6/20], global_step: 10440, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.142259, SARLoss: 0.571303, loss: 0.617993, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04564 s, avg_samples: 1.0, ips: 21.90927 samples/s, eta: 0:22:03, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:15] ppocr INFO: epoch: [6/20], global_step: 10450, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 3.029694, SARLoss: 0.420872, loss: 3.633149, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04714 s, avg_samples: 1.0, ips: 21.21549 samples/s, eta: 0:22:02, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:16] ppocr INFO: epoch: [6/20], global_step: 10460, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.158873, SARLoss: 0.399214, loss: 0.490357, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04524 s, avg_samples: 1.0, ips: 22.10436 samples/s, eta: 0:22:02, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:16] ppocr INFO: epoch: [6/20], global_step: 10470, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.131186, SARLoss: 0.001803, loss: 0.132989, avg_reader_cost: 0.00121 s, avg_batch_cost: 0.04654 s, avg_samples: 1.0, ips: 21.48643 samples/s, eta: 0:22:02, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:16] ppocr INFO: epoch: [6/20], global_step: 10480, lr: 0.000100, acc: 0.000000, norm_edit_dis: 0.933334, CTCLoss: 1.159066, SARLoss: 0.483803, loss: 1.356452, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04437 s, avg_samples: 1.0, ips: 22.53681 samples/s, eta: 0:22:01, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:17] ppocr INFO: epoch: [6/20], global_step: 10490, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.076519, SARLoss: 0.235447, loss: 0.621383, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04434 s, avg_samples: 1.0, ips: 22.55280 samples/s, eta: 0:22:01, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:17] ppocr INFO: epoch: [6/20], global_step: 10500, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.163159, SARLoss: 0.160111, loss: 0.342234, avg_reader_cost: 0.00109 s, avg_batch_cost: 0.04491 s, avg_samples: 1.0, ips: 22.26688 samples/s, eta: 0:22:00, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:18] ppocr INFO: epoch: [6/20], global_step: 10510, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.233302, SARLoss: 0.405152, loss: 0.645616, avg_reader_cost: 0.00111 s, avg_batch_cost: 0.04529 s, avg_samples: 1.0, ips: 22.08094 samples/s, eta: 0:22:00, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:18] ppocr INFO: epoch: [6/20], global_step: 10520, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.059339, SARLoss: 0.456828, loss: 0.518614, avg_reader_cost: 0.00110 s, avg_batch_cost: 0.04460 s, avg_samples: 1.0, ips: 22.42310 samples/s, eta: 0:21:59, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:19] ppocr INFO: epoch: [6/20], global_step: 10530, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.099699, SARLoss: 0.219123, loss: 0.326504, avg_reader_cost: 0.00107 s, avg_batch_cost: 0.04355 s, avg_samples: 1.0, ips: 22.96067 samples/s, eta: 0:21:59, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:19] ppocr INFO: epoch: [6/20], global_step: 10540, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.114926, SARLoss: 0.286571, loss: 0.605046, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04700 s, avg_samples: 1.0, ips: 21.27554 samples/s, eta: 0:21:58, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:20] ppocr INFO: epoch: [6/20], global_step: 10550, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 1.036043, SARLoss: 0.205101, loss: 1.595959, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04520 s, avg_samples: 1.0, ips: 22.12169 samples/s, eta: 0:21:58, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:20] ppocr INFO: epoch: [6/20], global_step: 10560, lr: 0.000100, acc: 0.000000, norm_edit_dis: 0.894738, CTCLoss: 4.074685, SARLoss: 0.407117, loss: 4.079236, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04543 s, avg_samples: 1.0, ips: 22.01368 samples/s, eta: 0:21:58, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:21] ppocr INFO: epoch: [6/20], global_step: 10570, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.403352, SARLoss: 0.009183, loss: 0.867398, avg_reader_cost: 0.00120 s, avg_batch_cost: 0.04527 s, avg_samples: 1.0, ips: 22.08819 samples/s, eta: 0:21:57, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:21] ppocr INFO: epoch: [6/20], global_step: 10580, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.240351, SARLoss: 0.351951, loss: 0.672864, avg_reader_cost: 0.00118 s, avg_batch_cost: 0.04322 s, avg_samples: 1.0, ips: 23.13863 samples/s, eta: 0:21:57, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# [2025/04/03 15:02:21] ppocr INFO: epoch: [6/20], global_step: 10590, lr: 0.000100, acc: 0.999990, norm_edit_dis: 1.000000, CTCLoss: 0.434274, SARLoss: 0.199187, loss: 0.633461, avg_reader_cost: 0.00105 s, avg_batch_cost: 0.04458 s, avg_samples: 1.0, ips: 22.43375 samples/s, eta: 0:21:56, max_mem_reserved: 422 MB, max_mem_allocated: 327 MB
# main proc 68758 exit, kill process group 68758main proc 69062 exit, kill process group 68758
# main proc 69060 exit, kill process group 68758
#
# ^C

# %%
# !cd /home/ubuntu/OCR/PaddleOCR/

# !python /home/ubuntu/OCR/PaddleOCR/tools/export_model.py \
    -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
    -o Global.pretrained_model=./output/v3_cyrillic_mobile/best_accuracy \
    Global.save_inference_dir=./inference/cyrillic_PP-OCRv3_rec
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/03 15:02:36] ppocr WARNING: Skipping import of the encryption module.
# W0403 15:02:37.800698 69080 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0403 15:02:37.805591 69080 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/04/03 15:02:42] ppocr INFO: load pretrain successful from ./output/v3_cyrillic_mobile/best_accuracy
# [2025/04/03 15:02:42] ppocr INFO: Export inference config file to ./inference/cyrillic_PP-OCRv3_rec/inference.yml
# Skipping import of the encryption module
# I0403 15:02:43.959717 69080 program_interpreter.cc:243] New Executor is Running.
# [2025/04/03 15:02:44] ppocr INFO: inference model is saved to ./inference/cyrillic_PP-OCRv3_rec/inference

# %%
# !cd /home/ubuntu/OCR/PaddleOCR/

# !python /home/ubuntu/OCR/PaddleOCR/tools/infer/predict_rec.py \
    --image_dir=/home/ubuntu/OCR/data/rec/test1/Гемоглобин_russia_combined1_0.jpg \
    --rec_model_dir=/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec \
    --rec_char_dict_path=/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt \
    --rec_image_shape="3, 48, 320"
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/03 15:02:55] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/04/03 15:02:57] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2025/04/03 15:02:58] ppocr INFO: Predicts of /home/ubuntu/OCR/data/rec/test1/Гемоглобин_russia_combined1_0.jpg:('Гемоглобин', 0.9999278783798218)

# %%
import os
import numpy as np
import cv2
import paddle
from paddle import inference
from glob import glob

# Configuration
model_path = '/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec'
dict_path = '/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt'
test_folder = '/home/ubuntu/OCR/data/rec/test'
ground_truth_file = '/home/ubuntu/OCR/data/rec/rec_gt_test.txt'
image_shape = "3, 48, 320"

# Load character dictionary
with open(dict_path, "rb") as f:
    lines = f.readlines()
    character_dict = {}
    for idx, line in enumerate(lines):
        line = line.decode('utf-8').strip("\n").strip("\r\n")
        character_dict[idx] = line

# Load ground truth data
gt_dict = {}
with open(ground_truth_file, 'r', encoding='utf-8') as f:
    for line in f:
        parts = line.strip().split('\t')
        if len(parts) >= 2:
            image_path = parts[0]
            image_name = os.path.basename(image_path)
            text = parts[1]
            gt_dict[image_name] = text

# Create paddle inference predictor
config = inference.Config(
    os.path.join(model_path, "inference.pdmodel"),
    os.path.join(model_path, "inference.pdiparams")
)
config.enable_use_gpu(500, 0)  # Using GPU
predictor = inference.create_predictor(config)

# Get input and output tensors
input_names = predictor.get_input_names()
input_tensor = predictor.get_input_handle(input_names[0])
output_names = predictor.get_output_names()
output_tensor = predictor.get_output_handle(output_names[0])

# Get image files
def get_image_files(folder):
    extensions = ['jpg', 'jpeg', 'png', 'bmp', 'tiff']
    image_files = []
    for ext in extensions:
        image_files.extend(glob(os.path.join(folder, f'*.{ext}')))
        image_files.extend(glob(os.path.join(folder, f'*.{ext.upper()}')))
    return sorted(image_files)

image_files = get_image_files(test_folder)

# Results tracking
total = 0
correct = 0
incorrect_samples = []

# Process each image
print(f"Processing {len(image_files)} images with GPU...")
for image_file in image_files:
    # Get ground truth
    image_name = os.path.basename(image_file)
    gt_text = gt_dict.get(image_name, "")
    
    if not gt_text:
        print(f"Warning: No ground truth found for {image_name}")
        continue
    
    # Read and preprocess image
    img = cv2.imread(image_file)
    if img is None:
        print(f"Error reading image: {image_file}")
        continue
        
    # Preprocess image
    img_c, img_h, img_w = [int(v) for v in image_shape.split(",")]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (img_w, img_h))
    img = np.transpose(img, (2, 0, 1))  # HWC to CHW
    img = img.astype('float32')
    img = img / 255.0
    img = img - 0.5
    img = img / 0.5
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    
    # Run inference
    input_tensor.copy_from_cpu(img)
    predictor.run()
    output = output_tensor.copy_to_cpu()
    
    # Process prediction (CTC decoding)
    pred_indices = np.argmax(output[0], axis=1)
    
    # Remove duplicate indices
    keep_indices = []
    prev_index = None
    for idx in pred_indices:
        if idx != prev_index:
            keep_indices.append(idx)
            prev_index = idx
    
    # Remove blank label (usually index 0)
    non_blank_indices = [idx for idx in keep_indices if idx > 0]
    
    # Convert indices to characters
    characters = [character_dict.get(idx, "") for idx in non_blank_indices]
    pred_text = "".join(characters)
    confidence = float(np.mean(np.max(output[0], axis=1)))
    
    # Update stats
    total += 1
    if pred_text == gt_text:
        correct += 1
    else:
        incorrect_samples.append({
            'image': image_name,
            'predicted': pred_text,
            'expected': gt_text,
            'confidence': confidence
        })

# Calculate accuracy
accuracy = correct / total if total > 0 else 0

# Print results
print("\n===== RESULTS =====")
print(f"Total images processed: {total}")
print(f"Correctly predicted: {correct}")
print(f"Accuracy: {accuracy:.2%}")

# Print incorrect predictions
if incorrect_samples:
    print("\n===== INCORRECT PREDICTIONS =====")
    for idx, sample in enumerate(incorrect_samples):
        print(f"{idx+1}. {sample['image']}:")
        print(f"   Predicted: '{sample['predicted']}' (conf: {sample['confidence']:.2f})")
        print(f"   Expected:  '{sample['expected']}'")
# Out:
# --- Running analysis [ir_graph_build_pass]
# --- Running analysis [ir_analysis_pass]
# --- Running IR pass [map_op_to_another_pass]
# --- Running IR pass [is_test_pass]
# --- Running IR pass [simplify_with_basic_ops_pass]
# --- Running IR pass [delete_quant_dequant_linear_op_pass]
# --- Running IR pass [delete_weight_dequant_linear_op_pass]
# --- Running IR pass [sparse_conv_optim_pass]
# --- Running IR pass [constant_folding_pass]
# --- Running IR pass [silu_fuse_pass]
# --- Running IR pass [conv_bn_fuse_pass]
# --- Running IR pass [conv_eltwiseadd_bn_fuse_pass]
# --- Running IR pass [embedding_eltwise_layernorm_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v2]
# --- Running IR pass [vit_attention_fuse_pass]
# --- Running IR pass [fused_multi_transformer_encoder_pass]
# --- Running IR pass [fused_multi_transformer_decoder_pass]
# --- Running IR pass [fused_multi_transformer_encoder_fuse_qkv_pass]
# --- Running IR pass [fused_multi_transformer_decoder_fuse_qkv_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_encoder_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_encoder_fuse_qkv_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_decoder_fuse_qkv_pass]
# --- Running IR pass [fuse_multi_transformer_layer_pass]
# --- Running IR pass [gpu_cpu_squeeze2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_reshape2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_flatten2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_map_matmul_v2_to_mul_pass]
# --- Running IR pass [gpu_cpu_map_matmul_v2_to_matmul_pass]
# --- Running IR pass [matmul_scale_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v3]
# --- Running IR pass [gpu_cpu_map_matmul_to_mul_pass]
# --- Running IR pass [fc_fuse_pass]
# --- Running IR pass [fc_elementwise_layernorm_fuse_pass]
# --- Running IR pass [conv_elementwise_add_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add2_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add_fuse_pass]
# --- Running IR pass [transpose_flatten_concat_fuse_pass]
# --- Running IR pass [transfer_layout_pass]
# --- Running IR pass [transfer_layout_elim_pass]
# --- Running IR pass [auto_mixed_precision_pass]
# --- Running IR pass [identity_op_clean_pass]
# --- Running IR pass [inplace_op_var_pass]
# --- Running analysis [ir_params_sync_among_devices_pass]
# --- Running analysis [adjust_cudnn_workspace_size_pass]
# --- Running analysis [inference_op_replace_pass]
# --- Running analysis [save_optimized_model_pass]
# --- Running analysis [ir_graph_to_program_pass]
# Processing 6 images with GPU...
#
# ===== RESULTS =====
# Total images processed: 6
# Correctly predicted: 0
# Accuracy: 0.00%
#
# ===== INCORRECT PREDICTIONS =====
# 1. 0.jpg:
#    Predicted: 'ьгэуп' (conf: 0.96)
#    Expected:  'ИНВИТРО'
# 2. 1.jpg:
#    Predicted: 'иооб' (conf: 0.96)
#    Expected:  'АННА'
# 3. 2.jpg:
#    Predicted: 'Дпм' (conf: 0.93)
#    Expected:  'Пол'
# 4. 3.jpg:
#    Predicted: 'лж' (conf: 0.97)
#    Expected:  'Жен'
# 5. 4.jpg:
#    Predicted: 'Cпиqбтуё' (conf: 0.97)
#    Expected:  'Возраст'
# 6. 5.jpg:
#    Predicted: 'иедпе' (conf: 0.99)
#    Expected:  '31 год'

# %%
from paddleocr import PaddleOCR

model_path = '/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec'
# model_path = '/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer'

ocr = PaddleOCR(
    use_gpu=True,  # Using GPU
    rec_model_dir=model_path,
    rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt',
    lang='ru'
)

result = ocr.ocr('/home/ubuntu/OCR/data/rec/test/1.jpg', cls=False, det=False)
print(result)
# Out:
# [2025/04/03 15:03:28] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ubuntu/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ubuntu/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ru', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gpu=True, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [[('AHHA', 0.9487234354019165)]]

# %% [markdown]
# # Cyrillic OCR with PaddleOCR
#
# This project implements Optical Character Recognition (OCR) for Cyrillic text using PaddleOCR. The system supports training, inference, and evaluation of text recognition models for Russian and other Cyrillic-based languages.
#
# ## Project Structure
#
# ```
# OCR/
# ├── PaddleOCR/                # PaddleOCR framework
# ├── model/                    # Pre-trained models
# │   ├── cyrillic_PP-OCRv3_rec_infer/
# │   └── cyrillic_PP-OCRv3_rec_train/
# ├── inference/                # Exported inference models
# │   └── cyrillic_PP-OCRv3_rec/
# ├── data/                     # Dataset
# │   ├── rec/
# │   │   ├── train/           # Training images
# │   │   ├── test/            # Test images
# │   │   ├── rec_gt_train.txt # Training ground truth
# │   │   └── rec_gt_test.txt  # Test ground truth
# │   └── det/                  # Detection dataset
# └── scripts/                  # Inference and utility scripts
# ```
#
# ## Features
#
# - **Cyrillic Text Recognition**: Specialized OCR for Russian and other Cyrillic scripts
# - **Model Training**: Scripts for training custom OCR models
# - **Model Export**: Tools to export trained models for inference
# - **Batch Inference**: Process multiple images and evaluate accuracy
# - **GPU Support**: Accelerated training and inference
#
# ## Setup & Installation
#
# 1. **Install Dependencies**:
#    ```bash
#    pip install paddlepaddle-gpu paddleocr opencv-python matplotlib numpy
#    ```
#
# 2. **Download Pre-trained Models**:
#    - Cyrillic recognition model: [cyrillic_ppocr_mobile_v2.0_rec_infer](https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/cyrillic_ppocr_mobile_v2.0_rec_infer.tar)
#    - Training model: [cyrillic_ppocr_mobile_v2.0_rec_train](https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/cyrillic_ppocr_mobile_v2.0_rec_train.tar)
#
# 3. **Clone PaddleOCR Repository**:
#    ```bash
#    git clone https://github.com/PaddlePaddle/PaddleOCR.git
#    ```
#
# ## Usage
#
# ### 1. Check Environment Setup
#
# Run the first notebook cell to verify GPU and system configurations:
# ```python
# import torch
# gpu_stats = torch.cuda.get_device_properties(0)
# print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
# ```
#
# ### 2. Verify PaddlePaddle Installation
#
# ```python
# import paddle
# print(paddle.__version__)
# print(paddle.is_compiled_with_cuda())
# paddle.utils.run_check()
# ```
#
# ### 3. Perform OCR Recognition
#
# ```python
# from paddleocr import PaddleOCR
#
# ocr = PaddleOCR(
#     use_gpu=True,
#     rec_model_dir='/path/to/model',
#     rec_char_dict_path='/path/to/dict/cyrillic_dict.txt',
#     lang='ru'
# )
#
# result = ocr.ocr('image.jpg', cls=False, det=False)
# print(result)
# ```
#
# ### 4. Train Custom Model
#
# ```bash
# cd /path/to/PaddleOCR/
# python tools/train.py \
#     -c configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
#     -o Global.pretrained_model=/path/to/pretrained/model
# ```
#
# ### 5. Export Model for Inference
#
# ```bash
# python tools/export_model.py \
#     -c configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
#     -o Global.pretrained_model=./output/v3_cyrillic_mobile/best_accuracy \
#     Global.save_inference_dir=./inference/cyrillic_PP-OCRv3_rec
# ```
#
# ### 6. Batch Inference and Evaluation
#
# Run the inference script to process test images and evaluate accuracy:
# ```bash
# python inference_script.py
# ```
#
# ## Configuration Options
#
# ### Recognition Model Parameters
#
# - `use_gpu`: Enable/disable GPU acceleration
# - `rec_model_dir`: Path to recognition model
# - `rec_char_dict_path`: Path to character dictionary
# - `lang`: Language code ('ru' for Russian)
# - `rec_image_shape`: Input image dimensions (channels, height, width)
#
# ### Training Parameters
#
# Configure training options in `cyrillic_PP-OCRv3_rec.yml`:
# - Learning rate
# - Batch size
# - Number of epochs
# - Data augmentation
# - Model architecture
#
# ## Model Details
#
# - **Architecture**: PP-OCRv3 with SVTR head
# - **Input Shape**: 3 × 48 × 320 (C×H×W)
# - **Character Set**: Cyrillic alphabet (Russian)
# - **Dictionary Path**: `ppocr/utils/dict/cyrillic_dict.txt`
#
# ## Performance
#
# - **Accuracy**: Varies by dataset and image quality
# - **Speed**: ~XX ms per image on GPU (depends on hardware)
# - **Model Size**: ~XX MB
#
# ## References
#
# - [PaddleOCR GitHub](https://github.com/PaddlePaddle/PaddleOCR)
# - [Multilingual Models Documentation](https://github.com/PaddlePaddle/PaddleOCR/blob/main/doc/doc_en/multi_languages_en.md)
# - [Cyrillic Model Configuration](https://github.com/PaddlePaddle/PaddleOCR/blob/main/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml)

# %%
# Check GPU Status and Memory
import torch

# Show current GPU memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)

print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# Verify Paddle Installation and CUDA Support
import paddle

# Check Paddle version and CUDA compatibility
print(f"Paddle version: {paddle.__version__}")
print(f"CUDA enabled: {paddle.is_compiled_with_cuda()}")
paddle.utils.run_check()

# Text Recognition using PaddleOCR with Cyrillic Model
from paddleocr import PaddleOCR

# Initialize PaddleOCR with Cyrillic recognition model
ocr = PaddleOCR(
    use_gpu=False,  # Try CPU first to eliminate CUDA issues
    rec_model_dir="/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer",
    rec_char_dict_path="/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt",
    lang="ru",  # Russian language for Cyrillic characters
)

# Run OCR on a test image (recognition only, no detection)
result = ocr.ocr("/home/ubuntu/OCR/data/rec/test/1.jpg", cls=False, det=False)
print(result)
# Out:
# GPU = Tesla T4. Max memory = 14.568 GB.
# 0.0 GB of memory reserved.
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# Paddle version: 3.0.0-rc1
# CUDA enabled: True
# Running verify PaddlePaddle program ...
# I0403 15:04:54.709229 69200 pir_interpreter.cc:1508] New Executor is Running ...
# W0403 15:04:54.712354 69200 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0403 15:04:54.713348 69200 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# I0403 15:04:59.705333 69200 pir_interpreter.cc:1531] pir interpreter is running by multi-thread mode ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# [2025/04/03 15:05:02] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ubuntu/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ubuntu/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ru', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [[('Aнна', 0.5968184471130371)]]

# %%
# # Train Cyrillic Recognition Model
# # Change to PaddleOCR directory and run training with pre-trained model
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/train.py \
#     -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
#     -o Global.pretrained_model=/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_train/best_accuracy

# %%
# Export Trained Model for Inference
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/export_model.py \
    -c /home/ubuntu/OCR/PaddleOCR/configs/rec/PP-OCRv3/multi_language/cyrillic_PP-OCRv3_rec.yml \
    -o Global.pretrained_model=./output/v3_cyrillic_mobile/best_accuracy \
    Global.save_inference_dir=./inference/cyrillic_PP-OCRv3_rec

# Run Inference with Exported Model
# !cd /home/ubuntu/OCR/PaddleOCR/
# !python /home/ubuntu/OCR/PaddleOCR/tools/infer/predict_rec.py \
    --image_dir=/home/ubuntu/OCR/data/rec/test1/Гемоглобин_russia_combined1_0.jpg \
    --rec_model_dir=/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec \
    --rec_char_dict_path=/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt \
    --rec_image_shape="3, 48, 320"
# Out:
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/03 15:08:11] ppocr WARNING: Skipping import of the encryption module.
# W0403 15:08:12.691797 69276 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.4, Runtime API Version: 11.7
# W0403 15:08:12.698235 69276 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/04/03 15:08:19] ppocr INFO: load pretrain successful from ./output/v3_cyrillic_mobile/best_accuracy
# [2025/04/03 15:08:19] ppocr INFO: Export inference config file to ./inference/cyrillic_PP-OCRv3_rec/inference.yml
# Skipping import of the encryption module
# I0403 15:08:21.361071 69276 program_interpreter.cc:243] New Executor is Running.
# [2025/04/03 15:08:21] ppocr INFO: inference model is saved to ./inference/cyrillic_PP-OCRv3_rec/inference
# /home/ubuntu/ocr_venv_py38/lib/python3.8/site-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/04/03 15:08:30] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/04/03 15:08:37] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2025/04/03 15:08:41] ppocr INFO: Predicts of /home/ubuntu/OCR/data/rec/test1/Гемоглобин_russia_combined1_0.jpg:('Гемоглобин', 0.9999278783798218)

# %%
# Cell 7: Test Recognition with Exported Model using PaddleOCR API
from paddleocr import PaddleOCR

# Path to the exported inference model
model_path = "/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec"
# Alternative path to pre-trained model
# model_path = '/home/ubuntu/OCR/model/cyrillic_PP-OCRv3_rec_infer'

# Initialize OCR with GPU
ocr = PaddleOCR(
    use_gpu=True,  # Using GPU for faster inference
    rec_model_dir=model_path,
    rec_char_dict_path="/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt",
    lang="ru",  # Russian language
)

# Run recognition on test image
result = ocr.ocr("/home/ubuntu/OCR/data/rec/test/1.jpg", cls=False, det=False)
print(result)
# Out:
# [2025/04/03 15:08:48] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ubuntu/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ubuntu/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ru', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gpu=True, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [[('AHHA', 0.9487234354019165)]]

# %%
# Cell 8: Full Inference and Evaluation Script
import os
import numpy as np
import cv2
import paddle
from paddle import inference
from glob import glob
import matplotlib.pyplot as plt

# Configuration - Edit these paths as needed
MODEL_PATH = "/home/ubuntu/OCR/inference/cyrillic_PP-OCRv3_rec"
DICT_PATH = "/home/ubuntu/OCR/PaddleOCR/ppocr/utils/dict/cyrillic_dict.txt"
TEST_FOLDER = "/home/ubuntu/OCR/data/rec/test"
GROUND_TRUTH_FILE = "/home/ubuntu/OCR/data/rec/rec_gt_test.txt"
IMAGE_SHAPE = "3, 48, 320"  # Channels, Height, Width


# Load character dictionary
def load_character_dict(dict_path):
    with open(dict_path, "rb") as f:
        lines = f.readlines()
        character_dict = {}
        for idx, line in enumerate(lines):
            line = line.decode("utf-8").strip("\n").strip("\r\n")
            character_dict[idx] = line
    return character_dict


# Load ground truth
character_dict = load_character_dict(DICT_PATH)
gt_dict = {}
with open(GROUND_TRUTH_FILE, "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split("\t")
        if len(parts) >= 2:
            image_path = parts[0]
            image_name = os.path.basename(image_path)
            text = parts[1]
            gt_dict[image_name] = text

print(f"Loaded {len(character_dict)} characters and {len(gt_dict)} ground truth labels")

# Setup predictor
config = inference.Config(
    os.path.join(MODEL_PATH, "inference.pdmodel"),
    os.path.join(MODEL_PATH, "inference.pdiparams"),
)
config.enable_use_gpu(500, 0)  # Using GPU with 500MB memory
predictor = inference.create_predictor(config)

# Get input and output tensors
input_names = predictor.get_input_names()
input_tensor = predictor.get_input_handle(input_names[0])
output_names = predictor.get_output_names()
output_tensor = predictor.get_output_handle(output_names[0])

# Get image files
extensions = ["jpg", "jpeg", "png", "bmp", "tiff"]
image_files = []
for ext in extensions:
    image_files.extend(glob(os.path.join(TEST_FOLDER, f"*.{ext}")))
    image_files.extend(glob(os.path.join(TEST_FOLDER, f"*.{ext.upper()}")))
image_files = sorted(image_files)

print(f"Found {len(image_files)} images in test folder")

# Results tracking
total = 0
correct = 0
incorrect_samples = []

# Process each image
print(f"Processing images with GPU...")
for image_file in image_files[
    :20
]:  # Limit to first 20 images for faster notebook execution
    # Get ground truth
    image_name = os.path.basename(image_file)
    gt_text = gt_dict.get(image_name, "")

    if not gt_text:
        print(f"Warning: No ground truth found for {image_name}")
        continue

    # Read and preprocess image
    img = cv2.imread(image_file)
    if img is None:
        print(f"Error reading image: {image_file}")
        continue

    # Preprocess image
    img_c, img_h, img_w = [int(v) for v in IMAGE_SHAPE.split(",")]
    img_display = img.copy()  # Save a copy for display
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (img_w, img_h))
    img = np.transpose(img, (2, 0, 1))  # HWC to CHW
    img = img.astype("float32")
    img = img / 255.0
    img = img - 0.5
    img = img / 0.5
    img = np.expand_dims(img, axis=0)  # Add batch dimension

    # Run inference
    input_tensor.copy_from_cpu(img)
    predictor.run()
    output = output_tensor.copy_to_cpu()

    # Process prediction (CTC decoding)
    pred_indices = np.argmax(output[0], axis=1)

    # Remove duplicate indices
    keep_indices = []
    prev_index = None
    for idx in pred_indices:
        if idx != prev_index:
            keep_indices.append(idx)
            prev_index = idx

    # Remove blank label (usually index 0)
    non_blank_indices = [idx for idx in keep_indices if idx > 0]

    # Convert indices to characters
    characters = [character_dict.get(idx, "") for idx in non_blank_indices]
    pred_text = "".join(characters)
    confidence = float(np.mean(np.max(output[0], axis=1)))

    # Update stats
    total += 1
    if pred_text == gt_text:
        correct += 1
        print(f"✓ {image_name}: '{pred_text}' (conf: {confidence:.2f})")
    else:
        incorrect_samples.append(
            {
                "image": image_name,
                "predicted": pred_text,
                "expected": gt_text,
                "confidence": confidence,
                "image_data": img_display,
            }
        )
        print(
            f"✗ {image_name}: Predicted '{pred_text}' but expected '{gt_text}' (conf: {confidence:.2f})"
        )

# Calculate accuracy
accuracy = correct / total if total > 0 else 0

# Print results
print("\n===== RESULTS =====")
print(f"Total images processed: {total}")
print(f"Correctly predicted: {correct}")
print(f"Accuracy: {accuracy:.2%}")

# Display some incorrect predictions with images
if incorrect_samples and len(incorrect_samples) > 0:
    print("\n===== DISPLAYING SOME INCORRECT PREDICTIONS =====")
    num_to_display = min(5, len(incorrect_samples))

    plt.figure(figsize=(15, 4 * num_to_display))
    for i in range(num_to_display):
        sample = incorrect_samples[i]
        plt.subplot(num_to_display, 1, i + 1)
        plt.imshow(cv2.cvtColor(sample["image_data"], cv2.COLOR_BGR2RGB))
        plt.title(
            f"Expected: '{sample['expected']}', Predicted: '{sample['predicted']}' (conf: {sample['confidence']:.2f})"
        )
        plt.axis("off")

    plt.tight_layout()
    plt.show()
# Out:
# Loaded 163 characters and 6 ground truth labels
# Found 6 images in test folder
# Processing images with GPU...
# ✗ 0.jpg: Predicted 'ьгэуп' but expected 'ИНВИТРО' (conf: 0.96)
# ✗ 1.jpg: Predicted 'иооб' but expected 'АННА' (conf: 0.96)
# ✗ 2.jpg: Predicted 'Дпм' but expected 'Пол' (conf: 0.93)
# ✗ 3.jpg: Predicted 'лж' but expected 'Жен' (conf: 0.97)
# ✗ 4.jpg: Predicted 'Cпиqбтуё' but expected 'Возраст' (conf: 0.97)
# ✗ 5.jpg: Predicted 'иедпе' but expected '31 год' (conf: 0.99)
#
# ===== RESULTS =====
# Total images processed: 6
# Correctly predicted: 0
# Accuracy: 0.00%
#
# ===== DISPLAYING SOME INCORRECT PREDICTIONS =====
# --- Running analysis [ir_graph_build_pass]
# --- Running analysis [ir_analysis_pass]
# --- Running IR pass [map_op_to_another_pass]
# --- Running IR pass [is_test_pass]
# --- Running IR pass [simplify_with_basic_ops_pass]
# --- Running IR pass [delete_quant_dequant_linear_op_pass]
# --- Running IR pass [delete_weight_dequant_linear_op_pass]
# --- Running IR pass [sparse_conv_optim_pass]
# --- Running IR pass [constant_folding_pass]
# --- Running IR pass [silu_fuse_pass]
# --- Running IR pass [conv_bn_fuse_pass]
# --- Running IR pass [conv_eltwiseadd_bn_fuse_pass]
# --- Running IR pass [embedding_eltwise_layernorm_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v2]
# --- Running IR pass [vit_attention_fuse_pass]
# --- Running IR pass [fused_multi_transformer_encoder_pass]
# --- Running IR pass [fused_multi_transformer_decoder_pass]
# --- Running IR pass [fused_multi_transformer_encoder_fuse_qkv_pass]
# --- Running IR pass [fused_multi_transformer_decoder_fuse_qkv_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_encoder_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_encoder_fuse_qkv_pass]
# --- Running IR pass [multi_devices_fused_multi_transformer_decoder_fuse_qkv_pass]
# --- Running IR pass [fuse_multi_transformer_layer_pass]
# --- Running IR pass [gpu_cpu_squeeze2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_reshape2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_flatten2_matmul_fuse_pass]
# --- Running IR pass [gpu_cpu_map_matmul_v2_to_mul_pass]
# --- Running IR pass [gpu_cpu_map_matmul_v2_to_matmul_pass]
# --- Running IR pass [matmul_scale_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v3]
# --- Running IR pass [gpu_cpu_map_matmul_to_mul_pass]
# --- Running IR pass [fc_fuse_pass]
# --- Running IR pass [fc_elementwise_layernorm_fuse_pass]
# --- Running IR pass [conv_elementwise_add_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add2_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add_fuse_pass]
# --- Running IR pass [transpose_flatten_concat_fuse_pass]
# --- Running IR pass [transfer_layout_pass]
# --- Running IR pass [transfer_layout_elim_pass]
# --- Running IR pass [auto_mixed_precision_pass]
# --- Running IR pass [identity_op_clean_pass]
# --- Running IR pass [inplace_op_var_pass]
# --- Running analysis [ir_params_sync_among_devices_pass]
# --- Running analysis [adjust_cudnn_workspace_size_pass]
# --- Running analysis [inference_op_replace_pass]
# --- Running analysis [save_optimized_model_pass]
# --- Running analysis [ir_graph_to_program_pass]
